# %%
from find_cluster_degs import *
adata = read('/home/zuolulu/spatialDEG/test/results.h5ad')
#genes = ['CAMK2N1','ENC1','HPCAL1','CCK','HOPX','MALAT1','SERPINE2','TESPA1','RASGRF2','FKBP1A']
adata = find_all_cluster_degs(adata,group='group',genes=None)
# Out:
# identifying top markers for each group: 19130it [04:33, 69.99it/s]
# identifying top markers for each group: 19130it [04:29, 71.02it/s]
# identifying top markers for each group: 19130it [04:17, 74.15it/s]
# identifying top markers for each group: 19130it [04:31, 70.55it/s]
# identifying top markers for each group: 19130it [04:18, 74.04it/s]
# identifying top markers for each group: 19130it [04:19, 73.60it/s]
# identifying top markers for each group: 19130it [04:24, 72.36it/s]

# %%
adata.uns['cluster_markers']
# Out:
# {'deg_table':            gene test_group       control_group  ratio_expr  diff_ratio_expr  \
#  0          ENC1          0  [1, 2, 3, 4, 5, 6]    0.998638         0.134954
#  1       CAMK2N1          0  [1, 2, 3, 4, 5, 6]    1.000000         0.058864
#  2        HPCAL1          0  [1, 2, 3, 4, 5, 6]    0.851499         0.427402
#  3          HOPX          0  [1, 2, 3, 4, 5, 6]    0.911444         0.386143
#  4      SERPINE2          0  [1, 2, 3, 4, 5, 6]    0.762943         0.371893
#  ...         ...        ...                 ...         ...              ...
#  13891      CMAS          6  [0, 1, 2, 3, 4, 5]    0.375000         0.042315
#  13892    ENTPD6          6  [0, 1, 2, 3, 4, 5]    0.478261         0.039971
#  13893      ATE1          6  [0, 1, 2, 3, 4, 5]    0.155797         0.037235
#  13894    HMGCS1          6  [0, 1, 2, 3, 4, 5]    0.543478         0.046232
#  13895    ATP2A2          6  [0, 1, 2, 3, 4, 5]    0.807971         0.058052
#
#           log2fc           pval           qval
#  0      0.617711  1.924148e-165  7.254038e-162
#  1      0.441469  1.569193e-146  3.943905e-143
#  2      1.333664  5.717012e-133  8.621254e-130
#  3      1.069297  3.711847e-121  4.664554e-118
#  4      1.092147   1.215817e-81   1.309608e-78
#  ...         ...            ...            ...
#  13891  0.273803   7.088556e-03   4.817534e-02
#  13892  0.217803   7.161836e-03   4.845752e-02
#  13893  0.533012   7.265607e-03   4.910520e-02
#  13894  0.182678   7.316471e-03   4.939427e-02
#  13895  0.119626   7.357155e-03   4.961405e-02
#
#  [13896 rows x 8 columns],
#  'de_genes': {0: ['ENC1',
#    'CAMK2N1',
#    'HPCAL1',
#    'HOPX',
#    'SERPINE2',
#    'CARTPT',
#    'LINC00507',
#    'CALB1',
#    'CUX2',
#    'CCK',
#    'OLFM1',
#    'SOWAHA',
#    'HS6ST3',
#    'PCDH8',
#    'EGR3',
#    'RCN1',
#    'CYP46A1',
#    'RASGRF2',
#    'ARPP19',
#    'GRIA4',
#    'NRGN',
#    'FKBP1A',
#    'LAMP5',
#    'CALB2',
#    'VSTM2A',
#    'FAM84A',
#    'ITPKA',
#    'FREM3',
#    'PENK',
#    'KCNG1',
#    'RBP4',
#    'C1QL2',
#    'LINC01007',
#    'NECAB2',
#    'CAMK2A',
#    'NPTXR',
#    'CALM1',
#    'TESPA1',
#    'CAMK4',
#    'ARPP21',
#    'PPP3CA',
#    'KCTD16',
#    'C11ORF87',
#    'JPH4',
#    'MEG3',
#    'YJEFN3',
#    'ADCYAP1',
#    'ACTN1',
#    'CNR1',
#    'C1ORF115',
#    'GPM6A',
#    'GRIA2',
#    'CTXN1',
#    'CBLN4',
#    'C2CD4C',
#    'CBLN2',
#    'NSG2',
#    'PPP4R4',
#    'KCNIP2',
#    'MEF2C',
#    'YWHAH',
#    'DGKB',
#    'DPP6',
#    'PRAG1',
#    'CA4',
#    'R3HDM1',
#    'PAK6',
#    'CXCL14',
#    'C14ORF132',
#    'RGS12',
#    'VSNL1',
#    'MAN1A1',
#    'SORBS2',
#    'SSTR1',
#    'CREG2',
#    'PPFIA2',
#    'GLRA3',
#    'TMEM65',
#    'GRIN1',
#    'CADM3',
#    'CACNB2',
#    'GNAL',
#    'GABRB2',
#    'NCDN',
#    'ATP2B1',
#    'TMOD1',
#    'THSD7A',
#    'PRKCA',
#    'CPNE6',
#    'FBLN7',
#    'PHYHIP',
#    'ANO3',
#    'FAM19A2',
#    'PTK2B',
#    'MKL2',
#    'FRRS1L',
#    'SLC12A5',
#    'SHANK3',
#    'DDRGK1',
#    'AKAP5',
#    'FAM19A1',
#    'ITPR1',
#    'PTPRF',
#    'ASS1',
#    'CDH22',
#    'NLK',
#    'RFX3',
#    'DDN',
#    'CKB',
#    'CAMKK1',
#    'RGS4',
#    'PNCK',
#    'GPR83',
#    'HPCA',
#    'CHRDL1',
#    'NRXN1',
#    'PLCB1',
#    'RTN4',
#    'PRRT2',
#    'ZBTB18',
#    'VIP',
#    'VSTM2L',
#    'SNN',
#    'AP1S1',
#    'EPHA4',
#    'LRRTM4',
#    'CRLF1',
#    'CHL1',
#    'SST',
#    'STXBP6',
#    'KIAA1211L',
#    'SIPA1L1',
#    'BTBD8',
#    'PDE2A',
#    'DOC2B',
#    'GRIN2B',
#    'ICAM5',
#    'PSD',
#    'PDZD2',
#    'HAPLN4',
#    'DGKA',
#    'MFSD4A',
#    'KCNIP4',
#    'C2ORF80',
#    'NGEF',
#    'C1QTNF4',
#    'MALAT1',
#    'CHN1',
#    'CELF5',
#    'KLF16',
#    'LNX1',
#    'ST6GALNAC5',
#    'FAM131A',
#    'MAN1C1',
#    'THRB',
#    'PIP5K1B',
#    'CAMKK2',
#    'LDB2',
#    'CDK5R1',
#    'NTRK3',
#    'SLC8A2',
#    'KCNV1',
#    'FLRT2',
#    'BEX1',
#    'GAD1',
#    'SDC3',
#    'PSD3',
#    'SLC2A13',
#    'WIF1',
#    'WASF1',
#    'RGS7',
#    'CDH13',
#    'EFR3B',
#    'SEZ6L',
#    'BTBD3',
#    'CHRM3',
#    'CALM3',
#    'GABBR2',
#    'SMAD3',
#    'GABRB3',
#    'CTXN3',
#    'MOB1B',
#    'PLPPR4',
#    'HS6ST1',
#    'NTM',
#    'JUN',
#    'CA10',
#    'PCSK1N',
#    'SHISA9',
#    'PKIG',
#    'PCDH7',
#    'ARNT2',
#    'VXN',
#    'TMEM178B',
#    'MIAT',
#    'LAMB1',
#    'KCNK3',
#    'SLC4A10',
#    'PRKCB',
#    'NDUFA4',
#    'CACNG3',
#    'BEGAIN',
#    'SESN3',
#    'ABLIM2',
#    'NPTN',
#    'DDX54',
#    'ZCCHC12',
#    'PMEPA1',
#    'DBNDD1',
#    'FBXO34',
#    'ARHGAP32',
#    'DCAF6',
#    'SSBP4',
#    'NRXN3',
#    'TAC3',
#    'SLC9A7',
#    'GABRD',
#    'BEX5',
#    'PDP1',
#    'PITPNM2',
#    'CNKSR2',
#    'TSC22D1',
#    'TMEM59L',
#    'MAST3',
#    'FBXL16',
#    'TP53I11',
#    'AC008780.2',
#    'NPTX2',
#    'MEF2D',
#    'L1CAM',
#    'SAA1',
#    'SLITRK4',
#    'FAM19A5',
#    'GRASP',
#    'LRRTM1',
#    'YWHAZ',
#    'COL26A1',
#    'BAIAP3',
#    'SLITRK5',
#    'AK5',
#    'PRRT1',
#    'ARL4A',
#    'SLC24A4',
#    'PIN1',
#    'ITM2C',
#    'GRIN2A',
#    'MEF2A',
#    'CACNA1A',
#    'KCNJ4',
#    'MYT1L',
#    'FOSL2',
#    'TSPYL1',
#    'TTYH3',
#    'MGAT5B',
#    'SNX3',
#    'ATP2B2',
#    'MED12L',
#    'C9ORF16',
#    'CRIP2',
#    'LZTS3',
#    'SYT16',
#    'ADGRB1',
#    'FABP4',
#    'GABRA4',
#    'SMARCA2',
#    'CRYM',
#    'UNC5A',
#    'NECAB1',
#    'PLD3',
#    'PIANP',
#    'MPPED2',
#    'NDST3',
#    'SCN2A',
#    'RTN4RL1',
#    'PTMS',
#    'NCKAP1',
#    'LMTK2',
#    'DAPK1',
#    'ATRNL1',
#    'AC110491.1',
#    'TENM2',
#    'TMEM130',
#    'PTPRN',
#    'CDH8',
#    'SSX2IP',
#    'GDA',
#    'IQSEC2',
#    'FRZB',
#    'TGFBR3L',
#    'PRMT8',
#    'SYNE1',
#    'CACNA2D1',
#    'SPON2',
#    'FRG1',
#    'AMPD2',
#    'KCNH4',
#    'ELMOD1',
#    'G0S2',
#    'SOBP',
#    'ROCK2',
#    'KCND2',
#    'PRKCG',
#    'AC116565.1',
#    'MAN1A2',
#    'PRR36',
#    'ERICH3',
#    'GPR6',
#    'HLF',
#    'FGF12',
#    'RGMB',
#    'LMO4',
#    'SYNGAP1',
#    'TM2D3',
#    'CAMK1D',
#    'PIP4K2C',
#    'HPCAL4',
#    'MTRNR2L12',
#    'ACTR3B',
#    'SLC6A1',
#    'CBARP',
#    'SPATS2L',
#    'MRPL33',
#    'RELN',
#    'CLSTN1',
#    'ARF5',
#    'FZD3',
#    'HOMER1',
#    'PDK2',
#    'PLEKHG5',
#    'PTPRO',
#    'RBFOX3',
#    'KIAA1549L',
#    'FABP7',
#    'AP3B2',
#    'PPP3R1',
#    'TSPYL2',
#    'GALNT18',
#    'TLE1',
#    'TUB',
#    'KCTD1',
#    'CA11',
#    'NFIB',
#    'CACNA1B',
#    'CTNNA2',
#    'CHST1',
#    'CEBPB',
#    'CPNE8',
#    'IPO5',
#    'UBALD1',
#    'EPB41L4B',
#    'PNISR',
#    'RHBDD2',
#    'PGBD5',
#    'LINC00937',
#    'DOC2A',
#    'SATB2',
#    'MYO1B',
#    'MRAS',
#    'ABI1',
#    'KLHL2',
#    'DUSP14',
#    'NRXN2',
#    'LYPD8',
#    'KCNJ12',
#    'FGFR1OP2',
#    'RAPH1',
#    'AC011603.3',
#    'SYNPO',
#    'GOLGA8B',
#    'MPC2',
#    'SLC29A4',
#    'STEAP2',
#    'SYT5',
#    'RASD1',
#    'ASPHD2',
#    'CDKL5',
#    'ACSL3',
#    'PTPRG',
#    'B4GALNT1',
#    'TMEM132B',
#    'KCNS1',
#    'LINGO1',
#    'ATP1A1',
#    'HRH2',
#    'SYBU',
#    'ATP1B2',
#    'LMO3',
#    'MIF',
#    'SLITRK1',
#    'MBOAT7',
#    'SLC22A17',
#    'DLGAP3',
#    'GARS',
#    'MOCS2',
#    'PRKDC',
#    'BAIAP2',
#    'ADAMTS8',
#    'DOCK4',
#    'NEGR1',
#    'KCNK1',
#    'PURB',
#    'SESN1',
#    'CAMK2B',
#    'CEBPD',
#    'ABI2',
#    'ARHGEF12',
#    'EPHX4',
#    'ABR',
#    'MAPK4',
#    'RBFOX1',
#    'DPF1',
#    'KCNC1',
#    'CIT',
#    'NECTIN3',
#    'ANXA11',
#    'PEG3',
#    'SLC12A8',
#    'EMX1',
#    'ENSA',
#    'CHRM1',
#    'SLC30A3',
#    'ZNRF1',
#    'UNC13A',
#    'MEIS3',
#    'CACNB3',
#    'KHDRBS2',
#    'PRKCD',
#    'CDK5',
#    'NRN1',
#    'CELF3',
#    'ANKRD12',
#    'TMEM158',
#    'ATRN',
#    'LRRC4',
#    'CELF1',
#    'GNG2',
#    'PCDH19',
#    'PI4KA',
#    'NTNG1',
#    'PPP1R21',
#    'RAB40C',
#    'DBN1',
#    'DOK6',
#    'FRY',
#    'ELK1',
#    'ST8SIA3',
#    'MAL2',
#    'PLAC9',
#    'CAP2',
#    'RAPGEFL1',
#    'DLG4',
#    'CMIP',
#    'TSPAN13',
#    'CCNG2',
#    'CDK17',
#    'ARL4C',
#    'GRM5',
#    'PDE7B',
#    'LZTS1',
#    'PSIP1',
#    'SYT13',
#    'EGR1',
#    'CLSTN3',
#    'PRR7',
#    'MAGI1',
#    'VGF',
#    'TAC1',
#    'LRP1',
#    'ATP6V1G2',
#    'PTPN5',
#    'MEGF8',
#    'CALM2',
#    'NETO2',
#    'HACD2',
#    'NCAM2',
#    'NOL4',
#    'ATP1B1',
#    'TMEM181',
#    'CUL2',
#    'PDPK1',
#    'SRSF7',
#    'CNTNAP2',
#    'MYCBP2',
#    'NSG1',
#    'GAS7',
#    'AC098850.3',
#    'CDC42EP3',
#    'SYNM',
#    'TRIM9',
#    'BRINP2',
#    'ANKRD34A',
#    'JPH1',
#    'KCNH1',
#    'PPFIBP1',
#    'SUMO2',
#    'MAPK6',
#    'KCNJ3',
#    'CALY',
#    'GSG1L',
#    'CD200',
#    'NORAD',
#    'VAMP2',
#    'FAM213B',
#    'XPO7',
#    'PLPPR5',
#    'TANC2',
#    'OSBPL8',
#    'LRFN4',
#    'LRFN5',
#    'IER5',
#    'SCG2',
#    'GPC1',
#    'GPR155',
#    'LPCAT4',
#    'ARFGEF3',
#    'THY1',
#    'MCHR1',
#    'PTPRN2',
#    'DLX6-AS1',
#    'AC005944.1',
#    'MT3',
#    'SCN3B',
#    'RTN4R',
#    'PCYOX1',
#    'DZIP3',
#    'RHOBTB2',
#    'CELF4',
#    'BDH1',
#    'ZNF184',
#    'TPST2',
#    'WNT10B',
#    'PLEKHA2',
#    'TNRC18',
#    'PDE1B',
#    'FAM213A',
#    'ADGRB2',
#    'NCEH1',
#    'MPP6',
#    'CNST',
#    'TEF',
#    'CACNA1E',
#    'PIK3R1',
#    'RTN4RL2',
#    'PAK5',
#    'ABHD8',
#    'C12ORF29',
#    'CAMKV',
#    'ARPC2',
#    'HLA-DQB1',
#    'KCNT1',
#    'RIMBP2',
#    'SLC26A4-AS1',
#    'BEX2',
#    'LMTK3',
#    'KIF3B',
#    'KALRN',
#    'TUBGCP4',
#    'DLG3',
#    'PACSIN1',
#    'GAP43',
#    'TMEM38A',
#    'FAM126B',
#    'RNF145',
#    'AHI1',
#    'KCNAB2',
#    'MINK1',
#    'VLDLR',
#    'MLF2',
#    'TNFRSF25',
#    'AL161772.1',
#    'ARHGAP33',
#    'B9D1',
#    'PAK3',
#    'TPD52L1',
#    'PNMT',
#    'TCAF1',
#    'COL5A2',
#    'GNB5',
#    'TCEAL6',
#    'RASD2',
#    'CASQ1',
#    'KCNK12',
#    'MGRN1',
#    'OLFM2',
#    'RUNDC3A',
#    'SLC25A27',
#    'ETV5',
#    'LY6H',
#    'LONRF2',
#    'AGK',
#    'GNG3',
#    'ADCY1',
#    'KIFC2',
#    'MAST1',
#    'PDE8B',
#    'CHD5',
#    'SUMO3',
#    'RBFA',
#    'SYTL2',
#    'NDUFAF2',
#    'ATP2A2',
#    'GGCT',
#    'RABL6',
#    'DGKI',
#    'CPEB4',
#    'IRS2',
#    'ATP2B1-AS1',
#    'SORBS1',
#    'HECW2',
#    'DUSP8',
#    'KCNN2',
#    'RFTN1',
#    'CAPZA2',
#    'ZNF667',
#    'RAB3A',
#    'PAK1',
#    'JPH3',
#    'PRNP',
#    'MZT1',
#    'TRIO',
#    'SLF1',
#    'KIAA1522',
#    'PCSK2',
#    'NEURL1',
#    'PRDM2',
#    'PPP3CB',
#    'CNIH2',
#    'PRR12',
#    'CLEC2L',
#    'NR2F1',
#    'KCNH3',
#    'RGS14',
#    'NEDD4L',
#    'H2AFZ',
#    'NCS1',
#    'LPL',
#    'TCF4',
#    'PPHLN1',
#    'DTNBP1',
#    'IFT22',
#    'MEIS2',
#    'MBD1',
#    'NDEL1',
#    'CNNM1',
#    'SLIT2',
#    'ARHGAP26',
#    'SV2A',
#    'VPS26B',
#    'SUGP2',
#    'SYNPR',
#    'NUDT11',
#    'PLCH2',
#    'KCNH5',
#    'CHGB',
#    'GRIK1',
#    'STYK1',
#    'ASTN1',
#    'KLHL23',
#    'RND1',
#    'RGS6',
#    'MAGEF1',
#    'GABRA3',
#    'PLPPR2',
#    'MGP',
#    'LZTFL1',
#    'KCNQ2',
#    'PPM1L',
#    'GFOD1',
#    'PIAS1',
#    'ATCAY',
#    'SFXN5',
#    'IGSF3',
#    'TOP1',
#    'MAP3K12',
#    'OBSL1',
#    'ABHD14A',
#    'CACNA1G',
#    'EIF4G3',
#    'SLC25A4',
#    'BTG1',
#    'PRKCI',
#    'SMPD3',
#    'QRICH1',
#    'NUDT4',
#    'PRPS2',
#    'C2CD2L',
#    'NWD2',
#    'CCDC106',
#    'ARHGEF9',
#    'INSIG2',
#    'RIMS3',
#    'MOSMO',
#    'BTBD10',
#    'MYH9',
#    'AGAP2',
#    'MED19',
#    'FXYD6',
#    'CSRNP3',
#    'CAPN5',
#    'OSBPL1A',
#    'RUNDC1',
#    'LRTM2',
#    'ZBTB43',
#    'SEMA5B',
#    'TSPYL4',
#    'DAGLA',
#    'MCTP1',
#    'CGREF1',
#    'BTBD9',
#    'SYT17',
#    'ATP2B3',
#    'CHMP3',
#    'OPN3',
#    'GABRA1',
#    'NPIPA1',
#    'RAMP1',
#    'FAT3',
#    'PDE4D',
#    'SMAP2',
#    'PIP4P1',
#    'NSA2',
#    'SCG5',
#    'TYRO3',
#    'FAM169A',
#    'TMEM132D',
#    'DLGAP2',
#    'RASL11B',
#    'CORO6',
#    'AJAP1',
#    'C20ORF27',
#    'EXOSC6',
#    'VEZT',
#    'ARL6',
#    'ATP2B4',
#    'PPM1K',
#    'CBX6',
#    'NDUFC2',
#    'LINC00599',
#    'SLITRK2',
#    'INPP4A',
#    'RPS6KL1',
#    'PKNOX2',
#    'MTPN',
#    'NUP50',
#    'RASGRF1',
#    'ZC3H15',
#    'LRRC73',
#    'TFG',
#    'WIPI2',
#    'MICU3',
#    'ATXN10',
#    'CHM',
#    'THRA',
#    'GPR22',
#    'TOMM40',
#    'FOXP1',
#    'NLGN2',
#    'KNDC1',
#    'ACTN4',
#    'CIB1',
#    'KCNC3',
#    'GOLGA8A',
#    'EPB41L2',
#    'IGSF21',
#    'CYCS',
#    'ATP5MD',
#    'GRINA',
#    'TSPAN14',
#    'RTN1',
#    'TLK1',
#    'NCAN',
#    'ANKMY2',
#    'KCNB1',
#    'LRP3',
#    'SHISA7',
#    'SPINT2',
#    'CDK20',
#    'ZNF365',
#    'LMBR1',
#    'TCEAL5',
#    'STAT4',
#    'SLC32A1',
#    'FAM160B1',
#    'ARF3',
#    'SLBP',
#    'GALNT11',
#    'TTC9',
#    'EPHB1',
#    'SYT7',
#    'KCNQ5',
#    'ERBB4',
#    'RGS5',
#    'RAB3C',
#    'PRKAR2B',
#    'WIPF2',
#    'ATP6V1H',
#    'MAP9',
#    'ADRB1',
#    'NSMF',
#    'DIAPH1',
#    'EPOP',
#    'SCN8A',
#    'GUCY1B1',
#    'ADD2',
#    'CACNA2D3',
#    'MGAT4B',
#    'FAM171B',
#    'P4HTM',
#    'USP11',
#    'SAA2',
#    'LANCL2',
#    'MAPK10',
#    'NPEPPS',
#    'FAM210B',
#    'ITFG1',
#    'GALNT2',
#    'CPNE5',
#    'RASL10A',
#    'STK11',
#    'FAM110B',
#    'C3ORF70',
#    'SUMO1',
#    'SLC39A10',
#    'MAGEE1',
#    'GULP1',
#    'C15ORF61',
#    'TRAPPC6B',
#    'LRFN2',
#    'JAM2',
#    'MT1G',
#    'CDC40',
#    'COQ10B',
#    'CRMP1',
#    'RNF165',
#    'SLC6A7',
#    'GRK2',
#    'NDFIP2',
#    'TIAM2',
#    'SPTBN2',
#    'PAM',
#    'OPRL1',
#    'FOXG1',
#    'FGF9',
#    'ACTN2',
#    'FBXO44',
#    'BRINP1',
#    'DCAF11',
#    'NAT8L',
#    'SAMD14',
#    'RNF44',
#    'OSTM1',
#    'NYAP1',
#    'KCND3',
#    'UBR5',
#    'ATL1',
#    'RITA1',
#    'AFAP1L2',
#    'C17ORF51',
#    'ACSL6',
#    'TNFSF12',
#    'NAGPA',
#    'SYNC',
#    'PLK2',
#    'MBLAC2',
#    'ZER1',
#    'RNF208',
#    'AFAP1',
#    'AASDHPPT',
#    'BLOC1S6',
#    'HMGCR',
#    'FGF14',
#    'CTSB',
#    'RNF150',
#    'GRIA3',
#    'SLC5A3',
#    'KCNJ9',
#    'PNOC',
#    'RBM6',
#    'GIT1',
#    'BTRC',
#    'HERC3',
#    'MYH10',
#    'NPDC1',
#    'LMO7',
#    'DGKE',
#    'HSP90B1',
#    'PNMA2',
#    'FXYD7',
#    'FAXC',
#    'MKNK1',
#    'STRIP2',
#    'LGMN',
#    'SRM',
#    'SEPT11',
#    'KCNJ6',
#    'GAD2',
#    'ZFYVE28',
#    'FGF13',
#    'RBM3',
#    'TSPAN17',
#    'IDH3G',
#    'EEF1A2',
#    'USP47',
#    'LSM14B',
#    'DIRAS1',
#    'SLC1A1',
#    'MICAL1',
#    'TMEM132A',
#    'SERTM1',
#    'MFGE8',
#    'CCDC136',
#    'WDR17',
#    'LINC00982',
#    'STXBP5',
#    'CCDC25',
#    'TUNAR',
#    'GPRIN1',
#    'FAM174B',
#    'SERINC3',
#    'SLC25A23',
#    'UBTF',
#    'RAB6B',
#    'FHL1',
#    'IDH2',
#    'LMBRD2',
#    'SEC14L1',
#    'MAP3K5',
#    'SLC2A3',
#    'HOOK1',
#    'ENTPD3',
#    'ZNF638',
#    'MIR124-2HG',
#    'ELAVL3',
#    'DGAT2',
#    'MRPS33',
#    'KIRREL3',
#    'ACSL4',
#    'UHRF1BP1L',
#    'RARB',
#    'CAMSAP2',
#    'MXD4',
#    'LGALS3',
#    'RNF112',
#    'BCL7B',
#    'PRKAA2',
#    'TNRC6B',
#    'AL365361.1',
#    'KPNA1',
#    'PREP',
#    'TBRG1',
#    'PRDM8',
#    'TNRC6C',
#    'TMEM161B-AS1',
#    'HTR2A',
#    'MCOLN1',
#    'CDYL2',
#    'DLGAP1',
#    'WFDC1',
#    'TM9SF4',
#    'FBXW7',
#    'NLRP1',
#    'AKAP8L',
#    'C11ORF95',
#    'ARPC5L',
#    'TNFRSF14',
#    'PPP4R2',
#    'SPTBN4',
#    'USP7',
#    'BCLAF1',
#    'NLGN4X',
#    'GARNL3',
#    'BAHD1',
#    'ACOT8',
#    'CHCHD10',
#    'ARID4A',
#    'SEZ6L2',
#    'CABP1',
#    'TPBG',
#    'SLC1A4',
#    'BAZ1B',
#    'SERPINI1',
#    'ST3GAL2',
#    'SUB1',
#    'RCN2',
#    'CTDSPL2',
#    'DENND1A',
#    'COPS7A',
#    'PPP1R7',
#    'ATRX',
#    'OTUB1',
#    'CD47',
#    'RPAIN',
#    'CHRD',
#    'PWWP2B',
#    'PLEKHA6',
#    'NPM3',
#    'NR3C2',
#    'VPS45',
#    'EIF2A',
#    'PTGES2',
#    ...],
#   1: ['TMSB10',
#    'PCP4',
#    'SNAP25',
#    'SYT1',
#    'TUBA1B',
#    'TUBB2A',
#    'PCP4L1',
#    'TRABD2A',
#    'STMN1',
#    'SMYD2',
#    'STMN2',
#    'SNCB',
#    'TTC9B',
#    'FRMPD2',
#    'FAM3C',
#    'NEFL',
#    'NDRG4',
#    'RORB',
#    'HPCA',
#    'UCHL1',
#    'ETV1',
#    'GABRA5',
#    'CAMK2D',
#    'BASP1',
#    'CLSTN2',
#    'SYN2',
#    'SNCG',
#    'NAP1L5',
#    'IPCEF1',
#    'EFHD2',
#    'DIRAS2',
#    'TOX',
#    'NREP',
#    'SNCA',
#    'CHGA',
#    'RTN1',
#    'ENO2',
#    'PFKP',
#    'FEZF2',
#    'HS3ST2',
#    'YWHAG',
#    'SLC17A7',
#    'MGLL',
#    'CDK14',
#    'SNRPN',
#    'SLC24A2',
#    'NAPB',
#    'CPLX1',
#    'STXBP1',
#    'HSP90AB1',
#    'PARM1',
#    'CCNI',
#    'KCNC2',
#    'NAP1L3',
#    'ATP6V1A',
#    'PRKAR1B',
#    'SERPINI1',
#    'NAP1L2',
#    'PFN2',
#    'CADPS2',
#    'NOV',
#    'HSPA8',
#    'TSPAN7',
#    'MPPED1',
#    'COX7A1',
#    'DCLK1',
#    'SSBP3',
#    'NRN1',
#    'PNMA8B',
#    'CXXC4',
#    'SV2A',
#    'NSF',
#    'TAGLN3',
#    'TRIM37',
#    'EIF4A2',
#    'ATP6V1B2',
#    'INPP5F',
#    'TOLLIP',
#    'PVALB',
#    'RXFP1',
#    'NEUROD6',
#    'RAB27B',
#    'SYN1',
#    'PGAM1',
#    'C16ORF45',
#    'UBE2QL1',
#    'NEK11',
#    'PCLO',
#    'PRUNE2',
#    'DNM1',
#    'MYO5A',
#    'KCNAB1',
#    'VSNL1',
#    'NUDT4',
#    'SATB1',
#    'MAP1B',
#    'IQSEC1',
#    'KCNA2',
#    'NCALD',
#    'NDUFA4',
#    'SYP',
#    'PTPRT',
#    'UQCRH',
#    'KIF17',
#    'VAT1L',
#    'MICAL2',
#    'NDUFA12',
#    'GOT1',
#    'RTN3',
#    'PGM2L1',
#    'GRIN3A',
#    'ATP1A3',
#    'ELAVL4',
#    'STX1A',
#    'CYP26B1',
#    'ELAVL2',
#    'BCL11A',
#    'SLC30A3',
#    'MDH1',
#    'PPIA',
#    'SNAP91',
#    'AP3M2',
#    'CRYM',
#    'PNMA8A',
#    'TMOD2',
#    'KCNF1',
#    'CAMK2G',
#    'HTR2A',
#    'TUBB4B',
#    'BNIP3',
#    'PDE1A',
#    'MOAP1',
#    'ATP5F1A',
#    'CFL1',
#    'BSN',
#    'HK1',
#    'KLHDC3',
#    'BEX4',
#    'EPS15',
#    'CCDC85A',
#    'ACOT7',
#    'GHITM',
#    'ATP5F1B',
#    'SV2B',
#    'GABRG2',
#    'PPP2R1A',
#    'CALM3',
#    'FABP3',
#    'RTN4R',
#    'IFITM10',
#    'SYNGR1',
#    'NEGR1',
#    'SLC39A10',
#    'PCDH19',
#    'SNX10',
#    'EEF1A2',
#    'NRSN1',
#    'ARL6IP1',
#    'TUBB',
#    'STMN3',
#    'HSP90AA1',
#    'RAB3A',
#    'PHACTR1',
#    'ADGRA1',
#    'NEFH',
#    'VOPP1',
#    'TRIB2',
#    'PCSK1',
#    'TM6SF1',
#    'PNMA2',
#    'BEX1',
#    'MGST3',
#    'SULT4A1',
#    'R3HDM2',
#    'FBLL1',
#    'UBE2E3',
#    'WSB2',
#    'FXYD6',
#    'GPRASP1',
#    'SUCLA2',
#    'GALNT17',
#    'TPI1',
#    'YARS',
#    'OXCT1',
#    'MAP1LC3A',
#    'STX1B',
#    'SAMD12',
#    'RASD2',
#    'LGALS1',
#    'GABRA1',
#    'CELF4',
#    'PHF24',
#    'CLSTN1',
#    'SYNGR3',
#    'SCN1B',
#    'CNRIP1',
#    'ERC2',
#    'GABRB2',
#    'PREPL',
#    'COX4I1',
#    'MAPK10',
#    'ATP1B1',
#    'DPY19L1',
#    'AP2M1',
#    'MDH2',
#    'G3BP2',
#    'LRRK1',
#    'NEUROD2',
#    'ZNF385B',
#    'MTCH1',
#    'OLFM1',
#    'ATP2A2',
#    'RPRM',
#    'RAB3C',
#    'SPHKAP',
#    'COX7C',
#    'SELENOH',
#    'FSTL5',
#    'ANXA6',
#    'HERC1',
#    'CPNE7',
#    'HRK',
#    'GAD1',
#    'KLC1',
#    'CHN1',
#    'SPTAN1',
#    'CAMKV',
#    'TUSC3',
#    'SORL1',
#    'COX8A',
#    'GPI',
#    'FBXW7',
#    'SLC25A22',
#    'PRDX5',
#    'CKMT1A',
#    'EPHB6',
#    'TIMM17A',
#    'KIF3C',
#    'ADRA1D',
#    'CEND1',
#    'CADPS',
#    'COX7A2',
#    'PID1',
#    'VAMP1',
#    'CHCHD10',
#    'OAZ1',
#    'ALPL',
#    'MAGED1',
#    'SEZ6',
#    'LDHB',
#    'NDUFA5',
#    'PIGX',
#    'TRMT9B',
#    'FTO',
#    'LONRF2',
#    'MAT2B',
#    'PJA2',
#    'CACNA1I',
#    'RAP1GAP',
#    'SPIN1',
#    'ITPK1',
#    'ASPH',
#    'KIF21A',
#    'FEM1B',
#    'PINK1',
#    'ABTB1',
#    'MAPK8IP2',
#    'SH3GL2',
#    'PRDM8',
#    'OAT',
#    'NRCAM',
#    'GRINA',
#    'NGRN',
#    'KLHL12',
#    'PACSIN1',
#    'RAB6B',
#    'OGDHL',
#    'PRKCE',
#    'NSG2',
#    'ATP5MD',
#    'PDE4A',
#    'CNTN3',
#    'GAL',
#    'ATP5MF',
#    'KCNQ3',
#    'APOL2',
#    'GPRASP2',
#    'SYNJ1',
#    'DNAJC6',
#    'IDS',
#    'MORF4L2',
#    'PNMA6A',
#    'RUNDC3A',
#    'GLRB',
#    'KRAS',
#    'MLLT11',
#    'PITHD1',
#    'GALNT8',
#    'PFKM',
#    'TSC22D1',
#    'SCG2',
#    'GNAS',
#    'ADD2',
#    'TTC7B',
#    'CPNE4',
#    'PTEN',
#    'PGK1',
#    'HECW1',
#    'TBC1D9',
#    'SLC12A5',
#    'COX6A1',
#    'DMXL2',
#    'AP2S1',
#    'DR1',
#    'CDS1',
#    'B4GAT1',
#    'NTN4',
#    'CNTNAP2',
#    'NDN',
#    'SNU13',
#    'COX5B',
#    'TACC2',
#    'HNRNPH2',
#    'ATP5MC3',
#    'TSPYL4',
#    'MRAP2',
#    'PCDH7',
#    'NUAK1',
#    'COX7B',
#    'NANOS3',
#    'STAC2',
#    'FNDC5',
#    'MARF1',
#    'GABARAPL1',
#    'MAP3K9',
#    'IFIT1',
#    'WDR47',
#    'CIAPIN1',
#    'PPA2',
#    'PRKAR1A',
#    'PAFAH1B1',
#    'ZDBF2',
#    'GPR158',
#    'LINC01963',
#    'PITPNM1',
#    'TMEM54',
#    'C1R',
#    'ARHGEF4',
#    'NLRP1',
#    'PLCH1',
#    'SPTSSB',
#    'SMARCD3',
#    'DLAT',
#    'RANBP9',
#    'WDR7',
#    'NELL1',
#    'SEMA6C',
#    'UNC13C',
#    'COPRS',
#    'GPM6A',
#    'CYTH2',
#    'CLTC',
#    'ARHGDIG',
#    'TRHDE',
#    'CDKN2D',
#    'PANK2',
#    'KIFAP3',
#    'CNIH3',
#    'HUNK',
#    'BEX5',
#    'TUBA4A',
#    'FSD1',
#    'FGF12',
#    'PCDH10',
#    'PPM1A',
#    'TBR1',
#    'DBP',
#    'KIF3A',
#    'HS3ST4',
#    'SAMD4A',
#    'TMEM160',
#    'RALYL',
#    'ATP6V1G2',
#    'CELF2',
#    'KCNIP3',
#    'HTATSF1',
#    'ATXN10',
#    'PWAR6',
#    'ACTG1',
#    'SYT4',
#    'POLR1D',
#    'SLC6A17',
#    'HINT3',
#    'CAMTA1',
#    'MYRIP',
#    'BECN1',
#    'AZIN1',
#    'C1S',
#    'VPS11',
#    'NDFIP1',
#    'APBA2',
#    'GLRX2',
#    'JAZF1',
#    'ATP5F1E',
#    'GNB1',
#    'PAK1',
#    'GUCY1B1',
#    'NDUFS2',
#    'CISD1',
#    'AES',
#    'SCN1A',
#    'SLC35F1',
#    'RBFOX2',
#    'PGAP1',
#    'LDHA',
#    'SMIM13',
#    'OPN3',
#    'HECA',
#    'LARGE1',
#    'MORF4L1',
#    'PART1',
#    'DYNC1LI1',
#    'UST',
#    'FLRT3',
#    'DLGAP4',
#    'PRPF19',
#    'PRKACB',
#    'ATP6AP2',
#    'SDHC',
#    'HDGFL3',
#    'CHMP4B',
#    'C1ORF52',
#    'PLBD2',
#    'TPRG1L',
#    'SOD1',
#    'PNPO',
#    'SLC20A1',
#    'RAC3',
#    'PPP2CA',
#    'SCG3',
#    'ATP5PO',
#    'DDX24',
#    'NBEA',
#    'SERINC1',
#    'APBB1',
#    'PRPF39',
#    'PSMC1',
#    'CHRM1',
#    'NARF',
#    'MAP7D2',
#    'COX7A2L',
#    'KHDRBS3',
#    'SOCS5',
#    'UBE2N',
#    'IDH3B',
#    'ZBTB18',
#    'RNF6',
#    'TMEM130',
#    'NECAP1',
#    'SLC25A4',
#    'SMS',
#    'SEZ6L2',
#    'NEFM',
#    'EBP',
#    'FXYD7',
#    'GABRG1',
#    'THOC7',
#    'AASDHPPT',
#    'PRDX2',
#    'IGHA1',
#    'SVOP',
#    'ATP13A2',
#    'ATXN7L3B',
#    'CPEB3',
#    'EIF5A',
#    'ITFG1',
#    'ATP5IF1',
#    'ENO1',
#    'SEPT3',
#    'CERK',
#    'TMEM151B',
#    'SLC8A1',
#    'ALDOA',
#    'GPR12',
#    'CYFIP2',
#    'FAM49A',
#    'RHEB',
#    'GNG3',
#    'SYT13',
#    'SIPA1L2',
#    'UBE2V2',
#    'CKMT1B',
#    'C12ORF57',
#    'DYNLT3',
#    'ZDHHC17',
#    'NDUFB2',
#    'ITPR1',
#    'VDAC2',
#    'ATP6V0A1',
#    'NDUFAF4',
#    'ZYX',
#    'EIF1B',
#    'SATB2',
#    'BLOC1S2',
#    'RAPGEF4',
#    'SKP1',
#    'BRSK2',
#    'APMAP',
#    'AAK1',
#    'PARVA',
#    'ARMC5',
#    'SCRT1',
#    'TNPO2',
#    'ST8SIA1',
#    'ATP8A2',
#    'CCDC184',
#    'GFOD2',
#    'MINOS1',
#    'CTNNBIP1',
#    'FAM216A',
#    'HRH3',
#    'SLIT1',
#    'MYT1L',
#    'TCEAL6',
#    'ARHGAP20',
#    'PPL',
#    'COX5A',
#    'PLPPR5',
#    'RAB6A',
#    'NRSN2',
#    'HIVEP2',
#    'SNTG1',
#    'HINT1',
#    'CABP1',
#    'HDDC2',
#    'CLVS1',
#    'INA',
#    'CCT2',
#    'CRH',
#    'CTNNA2',
#    'DGKZ',
#    'STAU2',
#    'SRGAP3',
#    'C3ORF14',
#    'ARL4C',
#    'AIDA',
#    'LIMK1',
#    'WASF3',
#    'USP33',
#    'MARCH2',
#    'GNPDA1',
#    'PRKAG2',
#    'AKAP12',
#    'CRIM1',
#    'KLF9',
#    'ABAT',
#    'APLP2',
#    'EXOSC6',
#    'TRNP1',
#    'OXR1',
#    'NUDC',
#    'ANAPC13',
#    'BEX3',
#    'CAP2',
#    'RAB15',
#    'NRBP1',
#    'SCOC',
#    'USP11',
#    'RNF11',
#    'NPM2',
#    'C11ORF74',
#    'FOXRED2',
#    'ATP6V0D1',
#    'CSPG5',
#    'PPFIA3',
#    'SOD2',
#    'AC009414.2',
#    'SLC9A1',
#    'PPP3CB',
#    'CLSTN3',
#    'PHYHIPL',
#    'KCNQ5',
#    'ANKRD46',
#    'VDAC3',
#    'MRS2',
#    'RYR2',
#    'GNB5',
#    'KIAA0513',
#    'NDUFB10',
#    'PRDX3',
#    'MYCBP2',
#    'EPHA4',
#    'PSMD12',
#    'PNMA8C',
#    'RAMMET',
#    'PTPN5',
#    'JPT1',
#    'ABHD10',
#    'RAB11A',
#    'GID8',
#    'MEF2C',
#    'LRRN3',
#    'DROSHA',
#    'AACS',
#    'PRMT2',
#    'VPS35',
#    'AKT3',
#    'FOXO3',
#    'THY1',
#    'MAPK9',
#    'NEXMIF',
#    'UTP4',
#    'CAMLG',
#    'TBC1D24',
#    'ERG28',
#    'FBXL15',
#    'NDP',
#    'PTGFRN',
#    'STAMBPL1',
#    'ACTR10',
#    'CLEC2L',
#    'DLGAP1',
#    'PKM',
#    'REEP5',
#    'CHGB',
#    'KCNC4',
#    'ANAPC1',
#    'YPEL5',
#    'LSAMP',
#    'PNMA1',
#    'EPHA5',
#    'PPP1R26',
#    'BCL2L2',
#    'TERF2IP',
#    'TCEAL2',
#    'CHST2',
#    'MED10',
#    'PDXK',
#    'SYBU',
#    'RABGAP1L',
#    'SAMM50',
#    'NELL2',
#    'OLA1',
#    'DDX1',
#    'RTL8C',
#    'HCN1',
#    'FABP6',
#    'DNAJA1',
#    'RAB26',
#    'CEP170B',
#    'ZNF106',
#    'SCAMP5',
#    'NDUFB4',
#    'RAB11FIP5',
#    'UQCRFS1',
#    'LINC00839',
#    'GMFB',
#    'TSC22D3',
#    'AC125616.1',
#    'NDUFAB1',
#    'UBE2M',
#    'YWHAB',
#    'RUSC2',
#    'ACTR1B',
#    'NKRF',
#    'CMC1',
#    'BEND6',
#    'AP2A2',
#    'RASGRP2',
#    'SLC25A5',
#    'KCNJ3',
#    'IMMT',
#    'ASNS',
#    'SLC2A3',
#    'GCC2',
#    'CRY2',
#    'STRAP',
#    'FBXL17',
#    'UTP18',
#    'GSTT2B',
#    'EFNA3',
#    'VPS37D',
#    'SCN2B',
#    'NPTXR',
#    'BTBD2',
#    'HSPA4L',
#    'ASAH1',
#    'GDAP1L1',
#    'DYNLRB1',
#    'ALAS1',
#    'PRKCZ',
#    'CPNE9',
#    'GAP43',
#    'HPRT1',
#    'TLN2',
#    'PCBP2',
#    'XKR4',
#    'ATP6V1D',
#    'CACNB4',
#    'TNFAIP8L1',
#    'SPOCK1',
#    'NUDT22',
#    'NDUFS5',
#    'CCDC92',
#    'UGP2',
#    'BRI3BP',
#    'GLRX',
#    'DEAF1',
#    'CRMP1',
#    'TAF1D',
#    'ISCU',
#    'MCRIP2',
#    'ARPC4',
#    'BHLHE40',
#    'EHD3',
#    'TTC3',
#    'NR1D1',
#    'EPS15L1',
#    'RNF157',
#    'PPA1',
#    'TENM4',
#    'SYT17',
#    'ATXN7L3',
#    'NUDCD3',
#    'NUDT21',
#    'WARS',
#    'AIFM1',
#    'EIF2S1',
#    'SSTR2',
#    'MIEF1',
#    'FAM98A',
#    'LINC01106',
#    'LUZP1',
#    'NAPEPLD',
#    'ZNF428',
#    'NDUFA2',
#    'NECAB3',
#    'ASTN2',
#    'L3MBTL2',
#    'FBXO44',
#    'RPP25',
#    'MAP2K4',
#    'NMNAT2',
#    'ZFP28',
#    'SCN2A',
#    'PLCL2',
#    'SRPK2',
#    'CGREF1',
#    'PTGES2',
#    'PDS5B',
#    'LMTK2',
#    'FNDC10',
#    'PPP1R2',
#    'ARPC1A',
#    'ATXN1',
#    'SPRN',
#    'AMPH',
#    'RNF146',
#    'MAST1',
#    'USP22',
#    'NDUFB8',
#    'GABBR2',
#    'EAPP',
#    'PSMB3',
#    'B3GALT2',
#    'GAPDH',
#    'HMGCS1',
#    'MAGEH1',
#    'SCG5',
#    'NAPA',
#    'MMP24OS',
#    'REX1BD',
#    'ALKBH6',
#    'PRPS1',
#    'TMEM126B',
#    'SMDT1',
#    'FEN1',
#    'TOMM70',
#    'MAFB',
#    'RPL39L',
#    'PKIA',
#    'TTYH3',
#    'ATF4',
#    'PTS',
#    'RGS2',
#    'POP7',
#    'INPP4A',
#    'FNDC4',
#    'AP2A1',
#    'FDX2',
#    'LSM11',
#    'ALDOC',
#    'ATP2B2',
#    'NPTN',
#    'PCNP',
#    'UBLCP1',
#    'F8',
#    'LRRC4C',
#    'EID2',
#    'WBP2',
#    'WASL',
#    'NCK2',
#    'SMAP1',
#    'SCAMP1',
#    'LGALS8',
#    'TAF13',
#    'BCAS4',
#    'IRGQ',
#    'RCN2',
#    'PSMA1',
#    'BCAS2',
#    'CHIC1',
#    'BLCAP',
#    'TRAPPC12',
#    'PODXL2',
#    'PSMD4',
#    'BEX2',
#    'COPS8',
#    'CDIPT',
#    'TMEM141',
#    'ELOC',
#    'PSMF1',
#    'TMEM41B',
#    'TMEM9',
#    'MRTO4',
#    'BCAT1',
#    'TMEM178A',
#    'TMEM237',
#    'NDUFB11',
#    'LINGO1',
#    'TUBG2',
#    'NDUFV3',
#    'FLOT2',
#    'GDI2',
#    'CACYBP',
#    'DYNC1I1',
#    'KCND3',
#    'PLXNA1',
#    'UBXN11',
#    'KLF10',
#    'COQ10B',
#    'IPO7',
#    'MADD',
#    'FAM20C',
#    'CTR9',
#    'CCDC186',
#    'MRPL46',
#    'ECM1',
#    'ATP5PD',
#    'CHCHD1',
#    'AP1G1',
#    'SERPINF1',
#    'NME1',
#    'CDK5R2',
#    'TMEM222',
#    'RIMS3',
#    'ACTL6B',
#    'NUDT14',
#    'STARD4',
#    'CLCN4',
#    'DCTN2',
#    'REEP2',
#    'NDUFA3',
#    'SUPV3L1',
#    'FRMPD4',
#    'FBXO32',
#    'C22ORF39',
#    'FBXO3',
#    'CHRNA4',
#    'THRB',
#    'EID1',
#    'IMP4',
#    'TTC39B',
#    'MARK4',
#    'YAF2',
#    'MRPL12',
#    'LAMTOR3',
#    'RFK',
#    'LGI1',
#    'WDR82',
#    'AL162231.1',
#    'SLC35B4',
#    'TSPYL2',
#    'HSDL1',
#    'AC138647.1',
#    'SYNDIG1',
#    'TTC19',
#    'PPM1L',
#    'SEC61A2',
#    'MOB4',
#    'KBTBD6',
#    'POLR3A',
#    'MAP2',
#    'B3GALNT1',
#    'MAGI3',
#    'PTPRN',
#    'UQCRC2',
#    'FAM155A',
#    'SHISAL1',
#    'TFRC',
#    'TPGS2',
#    'NSFL1C',
#    'FAM189A1',
#    'OLFM3',
#    'RBFOX3',
#    'SARAF',
#    'MATK',
#    'ANKRD13C',
#    'KCNK1',
#    'CHRNB2',
#    'DIRAS1',
#    'PPP3R1',
#    'NUB1',
#    'PAIP2',
#    'HCFC1R1',
#    'CD200',
#    'KLHL18',
#    'CCND2',
#    'AP1S2',
#    'AL022328.4',
#    'FKBP4',
#    'SEH1L',
#    'EEA1',
#    'BAALC',
#    'MCRIP1',
#    'FH',
#    'GPR162',
#    'HARS',
#    'UHMK1',
#    'SLC6A15',
#    'PDLIM7',
#    'DYNLL2',
#    'TSHZ3',
#    'WDFY1',
#    'TAC1',
#    'SPTB',
#    'OCEL1',
#    'CDK5',
#    'CLPTM1',
#    'STOX2',
#    'NOP56',
#    'FGF14',
#    'SCAI',
#    'TUBB3',
#    'SSBP2',
#    'LYSMD1',
#    'DNAJC18',
#    'DRAP1',
#    'PPM1H',
#    'SLC26A4-AS1',
#    'FAM49B',
#    'DDX3X',
#    'RBFOX1',
#    'TOMM5',
#    'MARK1',
#    'RASSF7',
#    'MTPN',
#    'NDUFC1',
#    'DPYSL2',
#    'ASPDH',
#    'SLC25A3',
#    'RABEPK',
#    'KCTD20',
#    'OCIAD2',
#    'RPL26L1',
#    'PCMT1',
#    'ARF3',
#    'PPP2R2C',
#    'UBE2K',
#    'CLIP3',
#    'PPIL1',
#    'YWHAZ',
#    'PUM1',
#    'MTMR14',
#    'EIF5',
#    'TXNRD1',
#    'PDZRN3',
#    'JAKMIP1',
#    'SPTBN2',
#    'KCMF1',
#    'SLC38A1',
#    'DUSP8',
#    'SLC25A14',
#    'ADAM22',
#    'PLCXD3',
#    'DCTN3',
#    'CCT4',
#    'STXBP5L',
#    'KLHL7',
#    'CACNG7',
#    'SLC30A9',
#    'ACAT2',
#    'PRRT1',
#    'LHX6',
#    'TFG',
#    'NEDD8',
#    'TMEM63B',
#    'NFYC',
#    'FBXO9',
#    'MAFG',
#    ...],
#   2: ['MALAT1',
#    'ACTA2',
#    'MGP',
#    'GFAP',
#    'MYL9',
#    'KRT19',
#    'VIM',
#    'MT1G',
#    'RELN',
#    'TAGLN',
#    'KRT8',
#    'TPM2',
#    'TFF3',
#    'FLNA',
#    'HBA2',
#    'AEBP1',
#    'CRABP2',
#    'NUPR1',
#    'H2AFJ',
#    'AZGP1',
#    'WFDC2'],
#   3: ['NEFL',
#    'NEFM',
#    'NEFH',
#    'SNCG',
#    'TUBA1B',
#    'SCN1B',
#    'VAMP1',
#    'NDUFA4',
#    'SYT2',
#    'YWHAH',
#    'UCHL1',
#    'INA',
#    'ATP1B1',
#    'NRGN',
#    'ATP1A1',
#    'GPX3',
#    'MDH1',
#    'GAP43',
#    'GAPDH',
#    'LGALS1',
#    'STMN2',
#    'MAP1B',
#    'HSPA8',
#    'NSF',
#    'LMO4',
#    'ATP1A3',
#    'EPDR1',
#    'SCN1A',
#    'VGF',
#    'HAPLN4',
#    'CCK',
#    'CABP1',
#    'GABRA1',
#    'PARM1',
#    'SNAP25',
#    'SNX10',
#    'RTN3',
#    'TPBG',
#    'ATP5MC3',
#    'DCLK1',
#    'SV2C',
#    'VSNL1',
#    'KCNA2',
#    'TAGLN3',
#    'NSG1',
#    'CRYM',
#    'EEF1A2',
#    'GABRD',
#    'KCNS1',
#    'UQCRH',
#    'CHGA',
#    'HOPX',
#    'AHNAK2',
#    'OLFM1',
#    'RTN1',
#    'TMX4',
#    'PGK1',
#    'PVALB',
#    'RORB',
#    'SNCB',
#    'C11ORF87',
#    'COX6A1',
#    'TPI1',
#    'VSTM2A',
#    'PKM',
#    'NGB',
#    'RIT2',
#    'STAC2',
#    'CA10',
#    'ATP5F1B',
#    'SCRT1',
#    'ATP6V1B2',
#    'PIN1',
#    'MAP7D2',
#    'CALM2',
#    'IGFBP2',
#    'TMSB4X',
#    'PRDX2',
#    'SCN4B',
#    'MEF2C',
#    'TRHDE',
#    'CTXN3',
#    'VDAC1',
#    'ENO2',
#    'ANXA6',
#    'RAB3A',
#    'ATP5MF',
#    'NDRG4',
#    'SPARCL1',
#    'OXR1',
#    'TSC22D1',
#    'BEX5',
#    'ATP2B2',
#    'GOT1',
#    'RCAN2',
#    'CKB',
#    'SLC30A3',
#    'DSTN',
#    'GABRB2',
#    'CLEC2L',
#    'OAZ1',
#    'ENC1',
#    'EXTL2',
#    'CLTC',
#    'COL5A2',
#    'YWHAG',
#    'CHP1',
#    'TUBB2A',
#    'ETS2',
#    'PPIA',
#    'GABRG2',
#    'CNTNAP2',
#    'MFGE8',
#    'ATP5PF',
#    'SLC6A17',
#    'RELL2',
#    'KRT5',
#    'SNRPN',
#    'EPHA4',
#    'TMEM132C',
#    'CHCHD10',
#    'CBLN4',
#    'KLC2',
#    'BEND5',
#    'SMIM37',
#    'SLC25A4',
#    'FABP3',
#    'TNNT2',
#    'CALY',
#    'GNG3',
#    'TIAM1',
#    'PGAM1',
#    'CDS1',
#    'ADAM23',
#    'SERPINI1',
#    'GHITM',
#    'STRBP',
#    'PHLDA2',
#    'PRDX5',
#    'NEUROD6',
#    'SPTSSB',
#    'PLCH1',
#    'SH3BGRL2',
#    'SCN8A',
#    'DYNLT3',
#    'PFKP',
#    'CPLX1',
#    'SOD1',
#    'COX8A',
#    'KIF5A',
#    'KCNC1',
#    'PINK1',
#    'ATP5IF1',
#    'TCERG1L',
#    'REEP2',
#    'FRMPD2',
#    'CCDC184',
#    'CISD1',
#    'FBXW7',
#    'TUBA4A',
#    'DIRAS1',
#    'NDUFAB1',
#    'CITED2',
#    'NPTN',
#    'PCDH8',
#    'ATP5MD',
#    'DLGAP1',
#    'ALDOC',
#    'NTNG1',
#    'ATP5MPL',
#    'BEND6',
#    'TESC',
#    'COX5B',
#    'SLC25A3',
#    'ATP6V1E1',
#    'CALM3',
#    'ISCU',
#    'COPS9',
#    'TESPA1',
#    'COX7B',
#    'CACYBP',
#    'GNAS',
#    'SYP',
#    'LYSMD2',
#    'MAP1LC3B',
#    'RGS4',
#    'SPOCK2',
#    'TUBB',
#    'REEP1',
#    'PCSK1',
#    'NAPB',
#    'COX4I1',
#    'NRN1',
#    'TPGS2',
#    'RNF208',
#    'CALM1',
#    'SLC22A17',
#    'MDH2',
#    'SV2A',
#    'HSPA12A',
#    'BASP1',
#    'DEXI',
#    'FGF12',
#    'BEX1',
#    'AMPH',
#    'AC105446.1',
#    'PRKAR1B',
#    'RAB6B',
#    'HSP90AA1',
#    'TMOD1',
#    'NDUFB1',
#    'ARL6IP1',
#    'NDUFA3',
#    'SYT4',
#    'MYO5A',
#    'RASGRF1',
#    'KLC1',
#    'PREPL',
#    'LYNX1',
#    'IGFBP6',
#    'PNMA3',
#    'STXBP1',
#    'OGDHL',
#    'C9ORF24',
#    'ACHE',
#    'PSMD12',
#    'RARB',
#    'COX7C',
#    'CEND1',
#    'RTL8C',
#    'KCNB1',
#    'RAP1GDS1',
#    'MGST3',
#    'CCDC136',
#    'AKR1B1',
#    'NECAB1',
#    'ELOVL4',
#    'ENPP5',
#    'TRIM37',
#    'SNAP91',
#    'RAB6A',
#    'DNAJC4',
#    'LDB2',
#    'CYCS',
#    'CYC1',
#    'COX5A',
#    'SEZ6L2',
#    'ARF5',
#    'GABARAPL1',
#    'NDUFA12',
#    'SYT13',
#    'GAL',
#    'CDH13',
#    'HTR2A',
#    'UQCRC1',
#    'ASNS',
#    'PCSK1N',
#    'FAM81A',
#    'SHD',
#    'STEAP2',
#    'FBXO34',
#    'SMARCA2',
#    'SCG5',
#    'UQCRFS1',
#    'ATP5F1A',
#    'STAU2',
#    'TOMM34',
#    'SLC12A5',
#    'SYBU',
#    'PCMT1',
#    'NSG2',
#    'RIMS3',
#    'OPTN',
#    'AP2M1',
#    'PFKM',
#    'GABBR2',
#    'CAPZA2',
#    'IDH3A',
#    'FAM84A',
#    'NDUFS1',
#    'CKMT1A',
#    'CTNNA2',
#    'UQCRB',
#    'ATP13A2',
#    'AKAP12',
#    'VDAC2',
#    'INPP5F',
#    'LPL',
#    'ATP6V1H',
#    'TCEAL2',
#    'VPS35',
#    'LIMK1',
#    'NORAD',
#    'SYNGR1',
#    'CD99L2',
#    'LRRC4',
#    'CFAP36',
#    'APBA2',
#    'NCDN',
#    'GUCY1B1',
#    'KCNIP4',
#    'SDHA',
#    'KCNQ5',
#    'BTBD8',
#    'EIF4A2',
#    'PITPNA',
#    'TMEM35A',
#    'CAMK2N2',
#    'HSP90AB1',
#    'PGP',
#    'YWHAZ',
#    'TUBB4B',
#    'TENM2',
#    'CPNE9',
#    'MORF4L1',
#    'GLRB',
#    'C1QBP',
#    'SGTB',
#    'ATP6V1F',
#    'HYOU1',
#    'COX7A2',
#    'HOMER1',
#    'NDUFV2',
#    'HINT1',
#    'NARS',
#    'SPTBN4',
#    'CDK5R1',
#    'LDHB',
#    'ZNF25',
#    'ATRNL1',
#    'PI4KA',
#    'SLU7',
#    'REEP5',
#    'POLR2E',
#    'NMNAT2',
#    'C2ORF80',
#    'ESYT1',
#    'UQCR10',
#    'FNDC4',
#    'FAM241B',
#    'ASPH',
#    'SYNJ1',
#    'PREP',
#    'NRXN1',
#    'DYNC1I1',
#    'CACNA2D3',
#    'TIAM2',
#    'NCALD',
#    'FKBP1B',
#    'FBXO9',
#    'SERPINF1',
#    'PIP4P2',
#    'GPI',
#    'PNCK',
#    'ANKRD29',
#    'SPTAN1',
#    'BRINP1',
#    'GLS2',
#    'GABRA4',
#    'SEC61G',
#    'SMYD2',
#    'OPCML',
#    'MAGED1',
#    'GLS',
#    'ELMOD1',
#    'TUBB3',
#    'KCNQ3',
#    'HPRT1',
#    'SATB1',
#    'PRSS3',
#    'NAP1L5',
#    'KCNC2',
#    'MRPL47',
#    'SLC25A5',
#    'RHEB',
#    'ATP6V0D1',
#    'SAA1',
#    'PTK2B',
#    'TMEM127',
#    'NUAK1',
#    'KIF3A',
#    'ELAVL2',
#    'UNC5D',
#    'STX1B',
#    'ANXA11',
#    'BCAP29',
#    'PRKACA',
#    'EIF5',
#    'COX6B1',
#    'ELAVL4',
#    'ZNF365',
#    'AKAP6',
#    'RALB',
#    'TMEM170B',
#    'TMEM163',
#    'NAPA',
#    'MIF',
#    'EIF4G3',
#    'PSMD8',
#    'RIMKLA',
#    'PTPRT',
#    'EPB41L3',
#    'SRD5A1',
#    'MPPED1',
#    'GRIN2A',
#    'BTBD10',
#    'FGF9',
#    'ATP6V1A',
#    'DBNDD1',
#    'ATP5F1C',
#    'LPCAT4',
#    'RAB1A',
#    'MOAP1',
#    'AAK1',
#    'GALNT9',
#    'NREP',
#    'CCDC85B',
#    'CTSB',
#    'ACAT2',
#    'ATL1',
#    'IRS2',
#    'B4GAT1',
#    'VSTM2L',
#    'ATP6V1D',
#    'VDAC3',
#    'PRDM8',
#    'BNIP3',
#    'ORC4',
#    'SERP2',
#    'CCM2',
#    'PPA2',
#    'B4GALT5',
#    'MRPL21',
#    'FAM69B',
#    'MX1',
#    'GPR6',
#    'NUDT14',
#    'EPHX4',
#    'THY1',
#    'SLC20A1',
#    'KIF3C',
#    'CACNB2',
#    'FAM78B',
#    'ACOT7',
#    'SNN',
#    'ELMO1',
#    'NDFIP1',
#    'TCEAL6',
#    'ATP5PB',
#    'NUDT4',
#    'TUSC2',
#    'UBC',
#    'TM6SF1',
#    'HCN1',
#    'CADM3',
#    'RNF175',
#    'HSPH1',
#    'ZBTB18',
#    'BAIAP3',
#    'RAB3C',
#    'KCNH5',
#    'PPME1',
#    'ADAM22',
#    'NTRK3',
#    'PDP1',
#    'PLXNA4',
#    'MAP9',
#    'RTN2',
#    'FLRT2',
#    'CDKN2D',
#    'MARCH2',
#    'WASL',
#    'MGAT5B',
#    'WIF1',
#    'CPEB3',
#    'ARPC5L',
#    'PPP2R2B',
#    'CDIP1',
#    'MINDY3',
#    'ATP5PD',
#    'CAB39',
#    'SLIT2',
#    'UQCR11',
#    'PTPRK',
#    'FJX1',
#    'NELL1',
#    'ACSL6',
#    'CAPNS1',
#    'GALNT8',
#    'COPRS',
#    'B4GALT6',
#    'SLC2A13',
#    'CTPS1',
#    'CYFIP2',
#    'TRIO',
#    'ATP1B3',
#    'RASD1',
#    'ATP5MC1',
#    'UBE2E2',
#    'ESRRA',
#    'DNAJA2',
#    'LRRC49',
#    'SUCLA2',
#    'TMEM63B',
#    'GTF3A',
#    'FBXO2',
#    'WSB2',
#    'SH3GL2',
#    'ZNF385A',
#    'LMBR1',
#    'SLC2A6',
#    'FDX2',
#    'B4GALNT1',
#    'DNM3',
#    'SLC4A3',
#    'HSPA4L',
#    'SCG2',
#    'CUX2',
#    'PNMA8B',
#    'QSOX1',
#    'UBE2O',
#    'GSTO1',
#    'OLFM2',
#    'ATP5F1D',
#    'PCSK2',
#    'OSBPL2',
#    'CDH22',
#    'UQCRQ',
#    'OPN3',
#    'MRPS30',
#    'ICA1',
#    'GNB5',
#    'KLK7',
#    'PITPNM1',
#    'TMEM74B',
#    'CCNI',
#    'FBXL19',
#    'NELL2',
#    'CBLN2',
#    'NDUFB5',
#    'MPP1',
#    'MAPK10',
#    'TTBK2',
#    'LUZP1',
#    'CHN1',
#    'SLC4A8',
#    'IMPDH1',
#    'MRPL3',
#    'ALDOA',
#    'HMOX2',
#    'PNMA8A',
#    'SPTBN2',
#    'DYNLL2',
#    'PIM2',
#    'CS',
#    'PRKAG2',
#    'TMEM14A',
#    'NFS1',
#    'NRSN1',
#    'GLRX2',
#    'DUSP6',
#    'KLHDC3',
#    'C12ORF10',
#    'TUBG1',
#    'NCEH1',
#    'PSMD2',
#    'RUSC1',
#    'TXNL1',
#    'NAA20',
#    'NDUFB2',
#    'TMEM250',
#    'MLLT11',
#    'APBB3',
#    'AC011603.2',
#    'BCAP31',
#    'NDUFV3',
#    'NAP1L2',
#    'SULT4A1',
#    'TAF13',
#    'ARL8B',
#    'KLHL29',
#    'SPRYD3',
#    'CRMP1',
#    'CERK',
#    'SNX14',
#    'CAPN1',
#    'ARPP21',
#    'NDUFA1',
#    'APBA1',
#    'TRNP1',
#    'SPINT2',
#    'FBXL2',
#    'OPA1',
#    'SLC26A4-AS1',
#    'GPX4',
#    'YWHAB',
#    'NDUFA9',
#    'ACOT13',
#    'CLTB',
#    'SYNGR3',
#    'SARS',
#    'PIK3R1',
#    'FBXW5',
#    'SLC45A4',
#    'KCTD9',
#    'TEX30',
#    'EID2',
#    'OLA1',
#    'RHOF',
#    'SELENOH',
#    'JDP2',
#    'HS6ST1',
#    'GTF2F1',
#    'MAP1S',
#    'PSMG3',
#    'NR2F1-AS1',
#    'FOCAD',
#    'STXBP5L',
#    'ATP5PO',
#    'EGFL7',
#    'RASSF3',
#    'BEX3',
#    'HNRNPUL2',
#    'FAIM2',
#    'FUNDC2',
#    'RGS7',
#    'GRK3',
#    'TPRG1L',
#    'KHDC1',
#    'GRM7',
#    'REX1BD',
#    'RAN',
#    'HERPUD1',
#    'CDC37',
#    'CCDC3',
#    'CAMK1G',
#    'FAM19A5',
#    'YARS',
#    'SLC9A6',
#    'SIAE',
#    'TMEM130',
#    'SDHB',
#    'GOT2',
#    'HAGHL',
#    'FAM135B',
#    'RASL10B',
#    'ANKRD9',
#    'AP2A1',
#    'MORF4L2',
#    'MAD2L1BP',
#    'HMGCR',
#    'C6ORF136',
#    'PDCD5',
#    'APLP2',
#    'RANBP2',
#    'NDRG3',
#    'HMGB3',
#    'JPT1',
#    'TMEM229B',
#    'TMEM132B',
#    'NDUFC1',
#    'APOL2',
#    'MRPS9',
#    'TM2D2',
#    'FUNDC1',
#    'CRELD1',
#    'FAM13A',
#    'CAMLG',
#    'CDH18',
#    'NCS1',
#    'SHANK2',
#    'DLD',
#    'RETREG2',
#    'CD59',
#    'MAGED2',
#    'NDUFB3',
#    'NR2F1',
#    'KIF21A',
#    'SMIM10L2B',
#    'STAT4',
#    'EFR3A',
#    'ECSIT',
#    'MPC2',
#    'MPRIP',
#    'OSTF1',
#    'ABHD8',
#    'PHYH',
#    'ACLY',
#    'GAS6',
#    'PPP3R1',
#    'DNAJC19',
#    'GLRX5',
#    'CDC123',
#    'NCK2',
#    'CNTNAP1',
#    'ITSN1',
#    'HS6ST3',
#    'MAN1C1',
#    'LDHA',
#    'DDT',
#    'NUDT22',
#    'TRPT1',
#    'GRIA4',
#    'POMGNT2',
#    'DPM1',
#    'ATF4',
#    'CAMK2A',
#    'GUCY1A2',
#    'PLK2',
#    'PLCB1',
#    'CCDC115',
#    'ASNA1',
#    'TMEM246',
#    'TOMM22',
#    'TXN',
#    'MRPS21',
#    'FAM19A2',
#    'MBOAT7',
#    'NAA38',
#    'UGCG',
#    'TMEM191B',
#    'ALKBH6',
#    'NUDT9',
#    'ARNTL',
#    'GLRX',
#    'GOLT1B',
#    'COPS5',
#    'SNPH',
#    'CERS6',
#    'HK1',
#    'DNAJB9',
#    'PPP5C',
#    'MAGEE1',
#    'ZYX',
#    'MATK',
#    'MRPL33',
#    'AC027031.2',
#    'DDX24',
#    'NNT',
#    'MRPS23',
#    'CARTPT',
#    'EMC4',
#    'MRPL16',
#    'CUL3',
#    'MYCBP2',
#    'MRPL12',
#    'RAB4A',
#    'SORL1',
#    'NDUFS5',
#    'NCKIPSD',
#    'RFK',
#    'GAD1',
#    'TMEM151B',
#    'KIFAP3',
#    'UROD',
#    'AARS',
#    'NUP93',
#    'NT5DC2',
#    'KLHL7',
#    'BLVRA',
#    'DCTN3',
#    'NAT8L',
#    'HEXIM1',
#    'DNAJA1',
#    'LDLR',
#    'LNX1',
#    'CKAP5',
#    'ATP6V1G2',
#    'TPD52',
#    'SLC1A1',
#    'PARD6A',
#    'FIG4',
#    'MAEA',
#    'RRM2B',
#    'EBNA1BP2',
#    'GBA2',
#    'NDUFB4',
#    'L1CAM',
#    'KALRN',
#    'ATXN7L3B',
#    'SMAP1',
#    'FAM216A',
#    'SLC27A4',
#    'NIPAL2',
#    'COL4A3BP',
#    'IDI1',
#    'NME1',
#    'TRPM2',
#    'RPL26L1',
#    'SUMO1',
#    'MRPS36',
#    'ATP6V1C1',
#    'ADGRL1',
#    'NCOA7',
#    'WSCD2',
#    'CSMD1',
#    'PNMA1',
#    'KCTD13',
#    'CHST1',
#    'ARL4C',
#    'TRIM32',
#    'DCTN1',
#    'ADGRF5',
#    'TTC1',
#    'DYNC1LI1',
#    'SLC39A10',
#    'MTRNR2L12',
#    'PCNX2',
#    'ATP2A2',
#    'RAB2A',
#    'ARHGEF11',
#    'FAM189B',
#    'QPCT',
#    'UBE3A',
#    'NDUFS4',
#    'TUNAR',
#    'KCNA1',
#    'CNOT7',
#    'COMMD5',
#    'MAL2',
#    'CNNM1',
#    'PRAG1',
#    'GRINA',
#    'STRAP',
#    'NT5DC3',
#    'SFXN1',
#    'COPS4',
#    'TMEM191C',
#    'CHIC1',
#    'CALB1',
#    'NRBP1',
#    'FAM102B',
#    'ARL2BP',
#    'ABHD14A',
#    'CIT',
#    'HSPA1B',
#    'KCNAB1',
#    'LONP1',
#    'HRH3',
#    'MAPK12',
#    'JAKMIP1',
#    'KHDRBS2',
#    'LRRC73',
#    'FNDC10',
#    'MAFB',
#    'PDE1B',
#    'CNIH3',
#    'CHAC1',
#    'BRD3OS',
#    'UGP2',
#    'SLC32A1',
#    'DDX41',
#    'ATP6V1G1',
#    'NANOS3',
#    'CNIH2',
#    'P4HTM',
#    'CARM1',
#    'PRPS2',
#    'STYK1',
#    'RAB11FIP5',
#    'FBXL15',
#    'NME7',
#    'PTPN3',
#    'TRAPPC1',
#    'GRIN1',
#    'POU3F2',
#    'ATG7',
#    'MARCH6',
#    'HS6ST2',
#    'NDUFA5',
#    'SLC38A1',
#    'PRPF19',
#    'F12',
#    'TMX2',
#    'KIF1A',
#    'BEX2',
#    'SACS',
#    'RHOBTB2',
#    'FAM234B',
#    'MICAL2',
#    'CNTN4',
#    'PAM',
#    'PSMD1',
#    'DYNLRB1',
#    'EFNA3',
#    'AP1S2',
#    'OCIAD2',
#    'CFL1',
#    'UBE2K',
#    'ELP1',
#    'HSDL1',
#    'AP1S1',
#    'GRAMD1B',
#    'POLR3H',
#    'RBFOX1',
#    'BOLA3',
#    'GNG13',
#    'PPA1',
#    'HARS',
#    'ATXN7L3',
#    'SCYL1',
#    'ASS1',
#    'TRUB2',
#    'NQO2',
#    'ANKRD39',
#    'SLC6A7',
#    'PRKAA1',
#    'EEF1E1',
#    'DENND5B',
#    'SNTG1',
#    'SYNPR',
#    'SMS',
#    'ACACA',
#    'IPO5',
#    'PPL',
#    'NDEL1',
#    'PPP2R2C',
#    'DOPEY1',
#    'PISD',
#    'ARMCX3',
#    'BUD31',
#    'CACNB1',
#    'UBE2E3',
#    'MRPL55',
#    'NOL3',
#    'PLEKHM3',
#    'KATNB1',
#    'LINGO1',
#    'RNF11',
#    'RAB9B',
#    'SCRG1',
#    'PANX2',
#    'COTL1',
#    'NIPSNAP1',
#    'TMEM145',
#    'PAK1',
#    'ARL6IP5',
#    'DPP10-AS1',
#    'NDUFC2',
#    'SMAP2',
#    'LSM4',
#    'TMEM70',
#    'BBS7',
#    'NFE2L1',
#    'DMXL2',
#    'STK39',
#    'PLD3',
#    'MFSD6',
#    'KCNH1',
#    'PSME3',
#    'SEMA4F',
#    'FAM57B',
#    'CAMK1D',
#    'HUNK',
#    'ANO5',
#    'NDUFS8',
#    'RILP',
#    'DPCD',
#    'GFPT1',
#    'SNX3',
#    'VPS36',
#    'CPNE4',
#    'NPM2',
#    'TMEM160',
#    'RRAGA',
#    'AC005944.1',
#    'CDK14',
#    'ABCC8',
#    'SH2D5',
#    'PNKD',
#    'SCAMP5',
#    'ADGRL2',
#    'HMGCS1',
#    'TUBG2',
#    'JAK1',
#    'DPYSL4',
#    'RASGRP2',
#    'NDUFB8',
#    'STS',
#    'GDAP1',
#    'ENTPD3',
#    'KIAA1549L',
#    'CHD5',
#    'DNASE1L1',
#    'LRRC20',
#    'COL6A1',
#    'FAM220A',
#    'NDUFA8',
#    'SUPT4H1',
#    'ASPDH',
#    'ZMAT4',
#    'PARP8',
#    'ISCA1',
#    'CAND1',
#    'ACVR1B',
#    'HDLBP',
#    'KIAA0232',
#    'DCTN2',
#    'CAMSAP2',
#    'SDR16C5',
#    ...],
#   4: ['MBP',
#    'PLP1',
#    'GFAP',
#    'TF',
#    'MOBP',
#    'CNP',
#    'CRYAB',
#    'S100B',
#    'CLDND1',
#    'ERMN',
#    'MAG',
#    'SPP1',
#    'PPP1R14A',
#    'SCD',
#    'BCAS1',
#    'RNASE1',
#    'MAL',
#    'SEPT4',
#    'HSPA2',
#    'LINC00844',
#    'CARNS1',
#    'OPALIN',
#    'CLDN11',
#    'MOG',
#    'PAQR6',
#    'TUBA1A',
#    'QKI',
#    'MARCKSL1',
#    'SELENOP',
#    'TMEM144',
#    'GPRC5B',
#    'PLEKHB1',
#    'PMP22',
#    'TTYH2',
#    'B2M',
#    'ENPP2',
#    'SCGB2A2',
#    'APOD',
#    'NKX6-2',
#    'SLC31A2',
#    'LPAR1',
#    'CD74',
#    'TSC22D4',
#    'NDRG1',
#    'QDPR',
#    'CNTN2',
#    'AQP1',
#    'MTURN',
#    'FGF1',
#    'PLLP',
#    'OLIG1',
#    'TP53INP2',
#    'GJC2',
#    'CSRP1',
#    'CNDP1',
#    'HIPK2',
#    'GSN',
#    'SEMA3B',
#    'SUN2',
#    'SLC44A1',
#    'FA2H',
#    'ELOVL1',
#    'PLEKHH1',
#    'CMTM5',
#    'UGT8',
#    'RPL13A',
#    'EFHD1',
#    'FAM107B',
#    'PRR18',
#    'AIF1L',
#    'HHIP',
#    'GPR37',
#    'IFI27',
#    'SLAIN1',
#    'LAMP2',
#    'CD9',
#    'FEZ1',
#    'SCGB1D2',
#    'AQP4',
#    'KRT17',
#    'CERS2',
#    'ANLN',
#    'C21ORF91',
#    'AGT',
#    'LHPP',
#    'RASSF2',
#    'KLK6',
#    'VWA1',
#    'MYRF',
#    'GLDN',
#    'NENF',
#    'SIRT2',
#    'PIP4K2A',
#    'PREX1',
#    'ABCA2',
#    'CPB1',
#    'HAPLN2',
#    'H3F3A',
#    'SYNGR2',
#    'PLA2G16',
#    'BOK',
#    'AMER2',
#    'EDIL3',
#    'TPPP3',
#    'SEMA4D',
#    'TMEM98',
#    'ASPA',
#    'S100A11',
#    'PHLDB1',
#    'PAIP2B',
#    'DAAM2',
#    'LITAF',
#    'MAP4K4',
#    'KRT19',
#    'HLA-B',
#    'VCAN',
#    'ST18',
#    'HLA-A',
#    'EVI2A',
#    'ZCCHC24',
#    'GALNT6',
#    'C1ORF198',
#    'AL359091.1',
#    'SPARC',
#    'RHOU',
#    'THBS2',
#    'NPC1',
#    'KRT18',
#    'ARHGEF37',
#    'VAMP3',
#    'PTP4A2',
#    'PADI2',
#    'LIPE',
#    'FGFR2',
#    'GJB1',
#    'OLIG2',
#    'TMEM63A',
#    'IFITM3',
#    'RTKN',
#    'SLC12A2',
#    'ITPKB',
#    'WIPF1',
#    'COL4A5',
#    'PKP4',
#    'PCSK6',
#    'CPLX3',
#    'AC018647.1',
#    'MT1E',
#    'CLIC4',
#    'CDKN1C',
#    'FOLH1',
#    'CERCAM',
#    'RNF13',
#    'CA2',
#    'TMEM125',
#    'FAM222A',
#    'DDR1',
#    'HBB',
#    'SEMA3E',
#    'SOX8',
#    'SLC6A9',
#    'ERBB3',
#    'CBR1',
#    'CTGF',
#    'RHOG',
#    'PLIN3',
#    'SEMA6A',
#    'AC092958.1',
#    'CDC42EP1',
#    'LGALS3BP',
#    'PSMB8',
#    'ID1',
#    'ZDHHC9',
#    'S1PR5',
#    'TMEM206',
#    'SOX10',
#    'KLHL32',
#    'ADAMTS4',
#    'DNM2',
#    'SLC9A3R1',
#    'HLA-DRA',
#    'RNF130',
#    'GLTP',
#    'MUC1',
#    'SFRP2',
#    'TJP1',
#    'CFL2',
#    'NFIA',
#    'EFS',
#    'FOS',
#    'DOCK1',
#    'PLPP2',
#    'WASF2',
#    'AMOTL2',
#    'TSPAN15',
#    'MTMR10',
#    'CHADL',
#    'FBXO7',
#    'SLCO1A2',
#    'MTUS1',
#    'RGMA',
#    'KIF1C',
#    'CALML5',
#    'FMNL2',
#    'GAL3ST1',
#    'JUP',
#    'ITGB8',
#    'HLA-C',
#    'ID3',
#    'PHGDH',
#    'EEF1D',
#    'RDX',
#    'TLE4',
#    'ADD3',
#    'GPR62',
#    'PAQR8',
#    'CDK18',
#    'EFNA1',
#    'USP54',
#    'CLDN7',
#    'PDE8A',
#    'S100A16',
#    'DYNC1I2',
#    'DYNC1LI2',
#    'NXPH3',
#    'LAMP1',
#    'COL9A2',
#    'WNK1',
#    'B3GAT2',
#    'IGFBP5',
#    'SNHG25',
#    'VEZF1',
#    'LIPA',
#    'NEAT1',
#    'TNFSF10',
#    'TNS2',
#    'SLC48A1',
#    'SLC35F1',
#    'CYP27A1',
#    'LINC00320',
#    'FAM69C',
#    'RHOC',
#    'RPRM',
#    'MEGF10',
#    'DOCK5',
#    'RBPJ',
#    'ZBTB20',
#    'HBA1',
#    'GATA3',
#    'AAMDC',
#    'GAB1',
#    'SPTLC2',
#    'RRBP1',
#    'TAX1BP3',
#    'NBR1',
#    'SEPT2',
#    'PXK',
#    'JAM3',
#    'PSAT1',
#    'GOLGA7',
#    'MID1IP1',
#    'REEP3',
#    'MAGT1',
#    'FAXDC2',
#    'SCARB2',
#    'H2AFJ',
#    'PTTG1IP',
#    'CD82',
#    'ISG15',
#    'MOB3B',
#    'RAB3IP',
#    'ERBIN',
#    'RGCC',
#    'TXNIP',
#    'HS3ST4',
#    'SALL1',
#    'PLPPR1',
#    'GAB2',
#    'RNH1',
#    'ADIRF',
#    'FN1',
#    'KCNJ10',
#    'DOHH',
#    'TBC1D12',
#    'CD99',
#    'SHTN1',
#    'NINJ2',
#    'TST',
#    'HIST1H2AC',
#    'AIF1',
#    'HLA-DRB5',
#    'SLC27A1',
#    'TFF3',
#    'CPNE2',
#    'PLPP3',
#    'AGAP1',
#    'CUEDC1',
#    'PMP2',
#    'PLXNB1',
#    'MVB12B',
#    'PIP',
#    'NEO1',
#    'COL3A1',
#    'KIAA0930',
#    'S100P',
#    'TMEM123',
#    'A1BG',
#    'ERBB2',
#    'TMEM165',
#    'ETNPPL',
#    'TMTC4'],
#   5: ['MOG',
#    'MOBP',
#    'MAG',
#    'MBP',
#    'PLP1',
#    'CRYAB',
#    'TF',
#    'CNP',
#    'PPP1R14A',
#    'ERMN',
#    'CLDN11',
#    'CARNS1',
#    'GFAP',
#    'PTGDS',
#    'CLDND1',
#    'HSPA2',
#    'SPP1',
#    'S100B',
#    'RNASE1',
#    'TMEM144',
#    'FTH1',
#    'SEPT4',
#    'NKX6-2',
#    'SELENOP',
#    'MAL',
#    'BCAS1',
#    'KLK6',
#    'SCD',
#    'ENPP2',
#    'PAQR6',
#    'LINC00844',
#    'OPALIN',
#    'MARCKSL1',
#    'APOD',
#    'ELOVL1',
#    'CNTN2',
#    'EFHD1',
#    'PLLP',
#    'GLDN',
#    'PLEKHB1',
#    'PLEKHH1',
#    'TUBA1A',
#    'TTYH2',
#    'GPRC5B',
#    'MYRF',
#    'QKI',
#    'UGT8',
#    'PMP22',
#    'CERCAM',
#    'FAM107B',
#    'LHPP',
#    'GJB1',
#    'LAMP2',
#    'SLC44A1',
#    'GPR37',
#    'TMEM63A',
#    'PADI2',
#    'EVI2A',
#    'PLA2G16',
#    'PIP4K2A',
#    'RASSF2',
#    'TSC22D4',
#    'CDKN1C',
#    'QDPR',
#    'CDC42EP1',
#    'CSRP1',
#    'APLP1',
#    'EDIL3',
#    'FGFR2',
#    'AL359091.1',
#    'ABCA2',
#    'CMTM5',
#    'PRR18',
#    'PTMA',
#    'CNDP1',
#    'FA2H',
#    'OLIG1',
#    'GSN',
#    'GPM6B',
#    'SEMA3B',
#    'ANLN',
#    'LPAR1',
#    'SUN2',
#    'BOK',
#    'HAPLN2',
#    'SLAIN1',
#    'FTL',
#    'FOLH1',
#    'FEZ1',
#    'TPPP3',
#    'RHOU',
#    'RPS12',
#    'ADAMTS4',
#    'NINJ2',
#    'CD9',
#    'C1ORF198',
#    'TP53INP2',
#    'JAM3',
#    'GLTP',
#    'CERS2',
#    'AIF1L',
#    'SOX8',
#    'PHLDB1',
#    'PLPP2',
#    'SIRT2',
#    'FGF1',
#    'AQP1',
#    'DAAM2',
#    'TMEM125',
#    'VWA1',
#    'NDRG1',
#    'SEMA4D',
#    'CBR1',
#    'EEF1A1',
#    'SOX10',
#    'GJC2',
#    'SLCO1A2',
#    'TMEM98',
#    'SLC31A2',
#    'PREX1',
#    'HIPK2',
#    'S1PR5',
#    'AC018647.1',
#    'ABCA8',
#    'HHIP',
#    'RPL30',
#    'SLC5A11',
#    'LRP2',
#    'CHADL',
#    'LITAF',
#    'AMER2',
#    'ERBB3',
#    'MTUS1',
#    'RPL28',
#    'COL4A5',
#    'CDK18',
#    'SLC48A1',
#    'FMNL2',
#    'EFS',
#    'SPOCK3',
#    'SHTN1',
#    'AC092958.1',
#    'SLC12A2',
#    'RAPGEF5',
#    'DOCK5',
#    'DDR1',
#    'SEPT8',
#    'OLIG2',
#    'PAIP2B',
#    'BIN1',
#    'RHOG',
#    'PCSK6',
#    'GPIHBP1',
#    'RPL37',
#    'RPL10',
#    'RPS8',
#    'LIPA',
#    'RTKN',
#    'PLXNB1',
#    'DNAH17',
#    'RGCC',
#    'HEPACAM',
#    'RPLP1',
#    'PLEKHG3',
#    'RPS27',
#    'PTP4A2',
#    'NENF',
#    'RNF130',
#    'CA2',
#    'ZDHHC9',
#    'CFL2',
#    'LIPE',
#    'CD82',
#    'GPR62',
#    'H3F3B',
#    'USH1C',
#    'LGALS3BP',
#    'LLGL1',
#    'ST18',
#    'AC093330.1',
#    'COL9A3',
#    'ASPA',
#    'ANKRD40',
#    'ZCCHC24',
#    'MTURN',
#    'USP54',
#    'RPL11',
#    'MAP4K4',
#    'DOCK10',
#    'RASGRP3',
#    'RNF13',
#    'C4ORF48',
#    'TSPAN15',
#    'CLIC4',
#    'JPT2',
#    'C21ORF91',
#    'AATK',
#    'MYO1D',
#    'RPL19',
#    'RDX',
#    'MTMR10',
#    'SYNGR2',
#    'CA14',
#    'RPL37A',
#    'CYP27A1',
#    'APLNR',
#    'REEP3',
#    'CNTNAP4',
#    'SYPL1',
#    'PHGDH',
#    'TP53TG5',
#    'COL9A2',
#    'VAMP3',
#    'B2M',
#    'ZEB2',
#    'PCBP4',
#    'RNH1',
#    'RPS13',
#    'WIPF1',
#    'RPS15A',
#    'ZNF536',
#    'SLC45A3',
#    'PRRG1',
#    'MVB12B',
#    'LAMP1',
#    'TRIM59',
#    'PXK',
#    'RPS23',
#    'FAXDC2',
#    'RPS29',
#    'SPARC',
#    'CREB5',
#    'PKP4',
#    'RPL34',
#    'PACS2',
#    'CYB5R2',
#    'ZDHHC20',
#    'FAU',
#    'RPS15',
#    'HIP1R',
#    'FOXN2',
#    'FNBP1',
#    'MCAM',
#    'GAB1',
#    'RPS27A',
#    'SEMA6A',
#    'IPO13',
#    'SYNJ2',
#    'C1ORF122',
#    'TMC6',
#    'ICOSLG',
#    'BACE1',
#    'NPC1',
#    'MID1IP1',
#    'GALNT15',
#    'RFFL',
#    'EEF1D',
#    'MAP7',
#    'KIAA0930',
#    'RPL21',
#    'TMBIM1',
#    'NCAM1',
#    'H3F3A',
#    'KCNJ10',
#    'ARHGAP23',
#    'RBP7',
#    'GOLGA7',
#    'HTRA1',
#    'SEPT2',
#    'GAL3ST1',
#    'FAM222A',
#    'CPM',
#    'PPDPF',
#    'KIAA1755',
#    'ADARB2-AS1',
#    'PAQR8',
#    'RPS3',
#    'CD74',
#    'ANP32B',
#    'PDE8A',
#    'LDLRAP1',
#    'RPL32',
#    'DYSF',
#    'SORT1',
#    'RPL12',
#    'LDB3',
#    'WNK1',
#    'RGS1',
#    'DPYSL5',
#    'SERF2',
#    'CTNNA1',
#    'TJAP1',
#    'KIF1C',
#    'KRT8',
#    'SCD5',
#    'BBX',
#    'DPYSL2',
#    'PDE1C',
#    'CUEDC1',
#    'PRR5L',
#    'RFTN2',
#    'PLPPR1',
#    'FBXO7',
#    'SECISBP2L',
#    'PAQR4',
#    'NTM-AS1',
#    'MAN2A1',
#    'PRKCSH',
#    'DYNC1I2',
#    'FRMD4B',
#    'TMEM189',
#    'TMEM235',
#    'RPS6',
#    'LARP6',
#    'SLC35D2',
#    'TMEM206',
#    'SALL1',
#    'SLCO3A1',
#    'TMTC4',
#    'RPS9',
#    'FIS1',
#    'PMP2',
#    'PLIN3',
#    'SCARB2',
#    'RPS19',
#    'TMEM165',
#    'UNC5B',
#    'ADIPOR2',
#    'RPL13',
#    'RALGDS',
#    'PSEN1',
#    'RPS16',
#    'SREBF1',
#    'THBS2',
#    'TMC7',
#    'RPS14',
#    'TPPP',
#    'CAHM',
#    'TMEM59',
#    'RPL39',
#    'RPS24',
#    'HPN',
#    'OTUD7B',
#    'RPS28',
#    'SPATA13',
#    'AQP4',
#    'RPL23A',
#    'CD81',
#    'CDR2L',
#    'AL358216.1',
#    'COL16A1',
#    'DNM2',
#    'KCNH8',
#    'GSTP1',
#    'CPNE2',
#    'STXBP3',
#    'TBCB',
#    'SMOC1',
#    'RPL13A',
#    'PSAT1',
#    'AGPAT4',
#    'ZBED3',
#    'MYLK',
#    'RHOB',
#    'DNAJB2',
#    'NEAT1',
#    'DBI',
#    'SNX22',
#    'ELOVL5',
#    'TUBB4A',
#    'SNHG25',
#    'NPC2',
#    'RPL4',
#    'LZTS2',
#    'RPL22',
#    'FNTA',
#    'TMTC2',
#    'S100A11',
#    'FAM124A',
#    'GLIPR2',
#    'CHST6',
#    'WSB1',
#    'RPLP2',
#    'GNAI1',
#    'PRCD',
#    'ENPP6',
#    'MAP3K11',
#    'TALDO1',
#    'ADARB2',
#    'CD22',
#    'PLD1',
#    'MT2A',
#    'CCDC88A',
#    'RAP1A',
#    'YBX1',
#    'RHOA',
#    'SERINC5',
#    'SPTLC2',
#    'ADD3',
#    'STMN4',
#    'SGK3',
#    'RPL8',
#    'P2RX7',
#    'PRDX1',
#    'RPS18',
#    'TTLL7',
#    'NKAIN2',
#    'WHRN',
#    'GATM',
#    'MYO9B',
#    'YWHAQ',
#    'HHATL',
#    'PDK4',
#    'DNER',
#    'HDAC11',
#    'RPS4X',
#    'SRCIN1',
#    'DAD1',
#    'ERBIN',
#    'TMEM258',
#    'TMCC3',
#    'CLMN',
#    'NACAD',
#    'BEST1',
#    'CPQ',
#    'SLC6A9',
#    'HMGN2',
#    'ITPKB',
#    'CYTH1',
#    'CADM4',
#    'TXNIP',
#    'RPS25',
#    'WASF2',
#    'TMEM123',
#    'SEPT7',
#    'TYMS',
#    'PHLPP1',
#    'PTTG1IP',
#    'TBC1D12',
#    'RPL18',
#    'FLNC',
#    'IFIT2',
#    'NRBP2',
#    'PSRC1',
#    'CRYL1',
#    'DOHH',
#    'APLN',
#    'PEA15',
#    'NEK3',
#    'KIF13B',
#    'TMSB4X',
#    'ZFYVE16',
#    'ACSL1',
#    'VCAN',
#    'TMEM151A',
#    'HIST2H2BE',
#    'SVIP',
#    'SLC13A3',
#    'FAR1',
#    'TFEB',
#    'EFNA1',
#    'MYO1E',
#    'ENPP4',
#    'DAZAP2',
#    'MAGT1',
#    'AC005921.2',
#    'MVP',
#    'MOB3B',
#    'ARHGAP22',
#    'ALAD',
#    'HIST1H2AC',
#    'AMOTL2',
#    'GCSH',
#    'ATP11A',
#    'GREM1',
#    'SFT2D2',
#    'SGK1',
#    'SERPINB6',
#    'CCDC152',
#    'PICALM',
#    'TJP1',
#    'A1BG',
#    'DIP2B',
#    'CD44',
#    'TJP2',
#    'GPD1',
#    'KLHL32',
#    'MYO10',
#    'TCF12',
#    'ENDOD1',
#    'ANAPC5',
#    'TMEM87A',
#    'TPRN',
#    'GAMT',
#    'DYNC1LI2',
#    'SNORC',
#    'LINC00320',
#    'NT5DC1',
#    'MYO6',
#    'PCDH9',
#    'FOS',
#    'METRN',
#    'RPS2',
#    'KANK1',
#    'ZFP36L1',
#    'EPN2',
#    'LIFR',
#    'ALCAM',
#    'RPS6KA2',
#    'FAM181B',
#    'RAPGEF3',
#    'RPS21',
#    'SEPT10',
#    'CRB2',
#    'HEPN1',
#    'TAX1BP3',
#    'RPL35A',
#    'C2ORF88',
#    'RPS5',
#    'LIMCH1',
#    'ATP5ME',
#    'CTSH',
#    'FAM53B',
#    'DHCR24',
#    'MEGF10',
#    'DENND5A',
#    'RPL29',
#    'ANGPTL2',
#    'FRYL',
#    'SFT2D1',
#    'CERS4',
#    'IFITM3',
#    'GAB2',
#    'SEC14L5',
#    'KRT18',
#    'NEO1',
#    'NKX2-2',
#    'ARRDC2',
#    'COMT',
#    'DST',
#    'HIP1',
#    'RBPJ',
#    'CD99',
#    'ITGB8',
#    'TPP1',
#    'PLOD3',
#    'SLC27A1',
#    'PIP',
#    'IGFBP5',
#    'MOSPD2',
#    'CCND1',
#    'TPT1',
#    'LDLRAD4',
#    'NUPR1',
#    'LANCL1',
#    'PTK2',
#    'TLE4',
#    'RARRES3',
#    'ATG4C',
#    'TGFA',
#    'RPL41',
#    'RBP1',
#    'ITM2B',
#    'TCFL5',
#    'MAPK8IP1',
#    'PLA2G4C',
#    'ABHD17B',
#    'NOTCH1',
#    'RPL5',
#    'TESK2',
#    'CPOX',
#    'IQGAP1',
#    'INF2',
#    'TMBIM6',
#    'SLC9A9',
#    'ZBTB20',
#    'CSF1',
#    'GALNT6',
#    'MCM7',
#    'RPL27A',
#    'SH3GL3',
#    'NFASC',
#    'ANKS1B',
#    'KIF5B',
#    'KTN1',
#    'SLC22A15',
#    'FSCN1',
#    'SNX18',
#    'ST3GAL4',
#    'OLMALINC',
#    'SNX1',
#    'CBFB',
#    'FAM13C',
#    'RPLP0',
#    'SLC25A13',
#    'GNAI2',
#    'CYP2J2',
#    'RPS10',
#    'COL18A1',
#    'FAM102A',
#    'DOCK1',
#    'EIF1',
#    'SLC4A2',
#    'LRRC8D',
#    'TTYH1',
#    'ETFRF1',
#    'ARHGEF37',
#    'OMG',
#    'JOSD2',
#    'MYO15B',
#    'CAT',
#    'NMB',
#    'CENPB',
#    'C9ORF3',
#    'LSS',
#    'RRBP1',
#    'SFRP2',
#    'RPS3A',
#    'COBL',
#    'RHOBTB3',
#    'RPL36',
#    'NDUFS7',
#    'ATP6V0E1',
#    'ICK',
#    'AAMDC',
#    'ITGB1',
#    'IQCK',
#    'MAN2A2',
#    'FAAH',
#    'CARHSP1',
#    'CAVIN1',
#    'CLN8',
#    'TRAF4',
#    'ARL8A',
#    'RPL38',
#    'TMED10',
#    'TNS1',
#    'MBNL2',
#    'ROM1',
#    'TMCC2',
#    'EML2',
#    'B3GAT2',
#    'APBB2',
#    'ANKIB1',
#    'PDE6B',
#    'FAM69C',
#    'S100A13',
#    'CD55',
#    'VSTM2B',
#    'C12ORF76',
#    'ROGDI',
#    'GRHPR',
#    'KLHL4',
#    'C3',
#    'KDSR',
#    'RPL35',
#    'CDC42EP2',
#    'FUT8',
#    'EMC2',
#    'SLC12A9',
#    'ZFP36L2',
#    'ZNF488',
#    'AC068888.1',
#    'RPS27L',
#    'TYROBP',
#    'ITGAV',
#    'ID3',
#    'CLK1',
#    'MTSS1',
#    'NACC2',
#    'CTDSP2',
#    'RNF141',
#    'HNRNPDL',
#    'VKORC1',
#    'HLA-DPA1',
#    'CTDSP1',
#    'PTPRD',
#    'DYNLT1',
#    'ATL3',
#    'AGT',
#    'FADS1',
#    'MAP7D1',
#    'MYL6',
#    'TSPO',
#    'RNF213',
#    'HADHB',
#    'POLR2G',
#    'LAPTM5',
#    'UXT',
#    'TMEM179B',
#    'FLNB',
#    'MPC1',
#    'NFE2L2',
#    'SNX6',
#    'ARHGAP21',
#    'HOMER3',
#    'C6ORF48',
#    'DDX5',
#    'BHLHE41',
#    'HSPA1A',
#    'GRM3',
#    'AGR2',
#    'CDK19',
#    'RPL26',
#    'KRTCAP2',
#    'CD63',
#    'KIAA1324L',
#    'EML3',
#    'AFMID',
#    'PHF2',
#    'KAT2B',
#    'EBF4',
#    'CCP110',
#    'GPSM2',
#    'ETFB',
#    'ABL1',
#    'PLCL1',
#    'NEK7',
#    'STRN',
#    'DDX17',
#    'ATOX1',
#    'INPP1',
#    'BAZ2B',
#    'NUDCD2',
#    'CDK5RAP3',
#    'PFN1',
#    'BDH2',
#    'HSBP1',
#    'COL1A2',
#    'RPL36A',
#    'PLS3',
#    'LMNA',
#    'ARHGEF1',
#    'RPL3',
#    'FAM177A1',
#    'HNRNPA2B1',
#    'SPART',
#    'RPS11',
#    'ZNF24',
#    'GLUL',
#    'LGI3',
#    'KIF13A',
#    'TLN1',
#    'RPL18A',
#    'AGA',
#    'BMI1',
#    'FAM107A',
#    'ACER3',
#    'NACA',
#    'MAPRE1',
#    'SBDS',
#    'DSEL',
#    'XIST',
#    'FANCL',
#    'HLA-A',
#    'SELENOW',
#    'MAP4K5',
#    'AC009041.2',
#    'ATP5MC2',
#    'PFDN5',
#    'TIMP2',
#    'GCA',
#    'EPB41L2',
#    'EEPD1',
#    'NUMA1',
#    'STAMBP',
#    'MUC1',
#    'SCGB2A2',
#    'NDRG2',
#    'TTC32',
#    'HMGB1',
#    'TARSL2',
#    'RPL7A',
#    'SLC25A1',
#    'ADAM15',
#    'RPS7',
#    'SAPCD2',
#    'ARAP1',
#    'AGAP1',
#    'SCAMP2',
#    'MRPL43',
#    'KCTD3',
#    'CETN3',
#    'NXPE3',
#    'RAB40B',
#    'PIK3C2B',
#    'CRTC3',
#    'ATM',
#    'FAM234A',
#    'RACK1',
#    'PSMB1',
#    'ERMP1',
#    'FAM3A',
#    'ADI1',
#    'SLC35B2',
#    'ALDH7A1',
#    'KCNN3',
#    'UBA52',
#    'RPL24',
#    'MAVS',
#    'NDST1',
#    'TRIP6',
#    'IRF2BP2',
#    'FUCA2',
#    'NIPAL3',
#    'CYBC1',
#    'FUS',
#    'SEMA4C',
#    'RPSA',
#    'GM2A',
#    'CD46',
#    'ANXA5',
#    'ADAM10',
#    'PLPP1',
#    'HMGN3',
#    'TMEM128',
#    'SPNS2',
#    'SLC44A2',
#    'IST1',
#    'GTF2I',
#    'ARPC5',
#    'TRIM2',
#    'PRTFDC1',
#    'ZNF652',
#    'HNRNPC',
#    'GNG5',
#    'JUND',
#    'POU3F3',
#    'SGCE',
#    'S100A10',
#    'SCRG1',
#    'SS18',
#    'MPDZ',
#    'PHC2',
#    'PABPC1',
#    'SLC6A8',
#    'USP31',
#    'LIG3',
#    'RSRP1',
#    'SIK3',
#    'MTDH',
#    'NSMCE4A',
#    'HNRNPA1',
#    'PON2',
#    'PPIB',
#    'JAKMIP3',
#    'EMC10',
#    'CYB5R3',
#    'CTTN',
#    'CPEB2',
#    'MT1E',
#    'EFCAB14',
#    'VPS4B',
#    'ATP8A1',
#    'FMC1',
#    'SLF2',
#    'KIAA1147',
#    'BMP7',
#    'ABHD6',
#    'SEC11C',
#    'SAR1B',
#    'COL3A1',
#    'NPB',
#    'AMPD3',
#    'WSCD1',
#    'VEZF1',
#    'CAPG',
#    'PRDX4',
#    'DICER1',
#    'RPL36AL',
#    'SMARCA5',
#    'NIPA1',
#    'WASHC4',
#    'NFIA',
#    'NKAIN4',
#    'STAG2',
#    'CNDP2',
#    'CNPY3',
#    'GNG7',
#    'MT1X',
#    'UBB',
#    'MFAP3L',
#    'EXOSC8',
#    'APOE',
#    'SFMBT2',
#    'KIF1B',
#    'PHLDA3',
#    'HMG20B',
#    'LRP10',
#    'HIST1H1C',
#    'TOB2',
#    'LRRC58',
#    'STRADB',
#    'TMED7',
#    'STX4',
#    'SEC62',
#    'GIPC1',
#    'PFKL',
#    'AIF1',
#    'IWS1',
#    'EHD1',
#    'SELENOS',
#    'RPS20',
#    'SEC22C',
#    'ANKRD13A',
#    'AK2',
#    'SNX9',
#    'UBL3',
#    'BUB3',
#    'S100A1',
#    'GALC',
#    'FXYD3',
#    'KCNMB4',
#    'MXI1',
#    'ADAP1',
#    'CEP97',
#    'CLASP2',
#    'RPL10A',
#    'SPX',
#    'H2AFX',
#    'CKS1B',
#    'CPPED1',
#    'NT5C',
#    'TNS2',
#    'STAT2',
#    'GFRA1',
#    'SMOX',
#    'FNTB',
#    'SHISA4',
#    'GCLC',
#    'CIRBP',
#    'TMBIM4',
#    'TAGLN2',
#    'PYCR2',
#    'IFI27',
#    'PIGU',
#    'AK3',
#    'TRAK2',
#    'CD164',
#    'ZNF83',
#    'SASH1',
#    'SGTA',
#    'TMEM170A',
#    'CASKIN2',
#    'CDC42SE1',
#    'LMBRD1',
#    'PIK3IP1',
#    'SSPN',
#    'POMGNT1',
#    'FBRS',
#    'SNRPG',
#    'DSCAML1',
#    'GTF2F2',
#    'CLASRP',
#    'MAU2',
#    'ST13',
#    'CNPPD1',
#    'DDIT4',
#    'PMF1',
#    'TRAFD1',
#    'APIP',
#    'ZFAND3',
#    'SESTD1',
#    'SF3B6',
#    'ALDH6A1',
#    'CCDC167',
#    'JPX',
#    'HEBP1',
#    'TMEM259',
#    'PGM3',
#    'KIAA0355',
#    'BCL7C',
#    'B3GAT1',
#    'ZNF775',
#    'SHROOM1',
#    'ACSS2',
#    'FECH',
#    'ENOPH1',
#    'ABHD17A',
#    'RPS26',
#    'SLC9A3R2',
#    'ZFAS1',
#    'SIGIRR',
#    'SCCPDH',
#    'NOP53',
#    'CPD',
#    'FRMD5',
#    'ELAVL3',
#    'EIF3G',
#    'POSTN',
#    'NCBP3',
#    'SLC16A1',
#    'TROVE2',
#    'PAK2',
#    'SSNA1',
#    'TP53BP2',
#    'CORO1B',
#    'MAPKAPK2',
#    'HADHA',
#    'RAB33A',
#    ...],
#   6: ['KRT17',
#    'NR4A2',
#    'SYT1',
#    'SNAP25',
#    'DIRAS2',
#    'SLC17A7',
#    'SMIM32',
#    'CHN1',
#    'CPLX2',
#    'B3GALT2',
#    'CCK',
#    'DKK3',
#    'ISLR',
#    'RTN1',
#    'TMSB10',
#    'GPM6A',
#    'MAP2K1',
#    'TBR1',
#    'MAP1B',
#    'CPB1',
#    'SLC35F1',
#    'CPE',
#    'TUBA1B',
#    'THY1',
#    'SSTR2',
#    'HS3ST2',
#    'THEMIS',
#    'TUBA4A',
#    'YWHAG',
#    'NTNG2',
#    'TUBB2A',
#    'NELL2',
#    'SCN3B',
#    'FBXL16',
#    'MAP2',
#    'SEMA3E',
#    'PRKCB',
#    'MOAP1',
#    'MMD',
#    'RXFP1',
#    'AK5',
#    'C16ORF45',
#    'SPARCL1',
#    'TSPAN7',
#    'DNM1',
#    'PI4KA',
#    'TSPYL1',
#    'NAPB',
#    'DACH1',
#    'ARPP19',
#    'PPP3CB',
#    'ADCY1',
#    'TMEM59L',
#    'ATP2B1',
#    'CHGB',
#    'VSNL1',
#    'PGAM1',
#    'LRP1B',
#    'COX7A1',
#    'SLC24A2',
#    'SYT4',
#    'CLSTN2',
#    'SLC1A2',
#    'GRIK3',
#    'EPHB6',
#    'HS3ST4',
#    'UNC13A',
#    'NDFIP2',
#    'CTXN1',
#    'KLC1',
#    'SNCB',
#    'PPP2R1A',
#    'SV2B',
#    'LDHB',
#    'STMN2',
#    'SNCA',
#    'BSN',
#    'UBE2QL1',
#    'MAPK1',
#    'GNG2',
#    'RGS4',
#    'CAP2',
#    'RAP1GAP2',
#    'UCHL1',
#    'DDAH1',
#    'STMN1',
#    'IPCEF1',
#    'DGKZ',
#    'CNTN1',
#    'SIRPA',
#    'RPH3A',
#    'CALM3',
#    'SPOCK1',
#    'SEPT3',
#    'STX1A',
#    'MTPN',
#    'PPP3CA',
#    'SCG5',
#    'SNRPN',
#    'PWAR6',
#    'NPTX1',
#    'PIP5K1C',
#    'SYN2',
#    'BASP1',
#    'ANXA6',
#    'CDH6',
#    'SYNJ1',
#    'DCLK1',
#    'PRKCG',
#    'CPNE5',
#    'PRKCE',
#    'NELL1',
#    'RBFOX1',
#    'STXBP1',
#    'MLLT11',
#    'MAST3',
#    'BAIAP2',
#    'CLSTN1',
#    'DLGAP1',
#    'GABRA5',
#    'DNAJC6',
#    'FAM213A',
#    'NCALD',
#    'SPRYD3',
#    'CRTAC1',
#    'DYNLL1',
#    'HSP90AB1',
#    'KIFAP3',
#    'PTPRN',
#    'EFHD2',
#    'TMEM178A',
#    'EPHA5',
#    'KRT19',
#    'GNAS',
#    'PDE1A',
#    'CPNE4',
#    'NGEF',
#    'PCSK2',
#    'SLC8A1',
#    'G3BP2',
#    'ZFAND5',
#    'RAB6B',
#    'NRCAM',
#    'UHMK1',
#    'NPTN',
#    'EEF1A2',
#    'SCN2A',
#    'PCDH10',
#    'FABP3',
#    'LMO4',
#    'LY6H',
#    'TMEFF2',
#    'MAPK9',
#    'HSP90AA1',
#    'PNMA2',
#    'PPP3R1',
#    'PPP1R1A',
#    'SCN1B',
#    'KCNF1',
#    'PCMT1',
#    'FDPS',
#    'FAM198B',
#    'NORAD',
#    'NDRG4',
#    'NSF',
#    'WASF1',
#    'BEX3',
#    'CABP1',
#    'LDHA',
#    'JPH3',
#    'COX6C',
#    'EHD3',
#    'KCNN1',
#    'NPY1R',
#    'SYNGR3',
#    'RTN3',
#    'DOC2A',
#    'SCAMP5',
#    'GCC2',
#    'RASGRP1',
#    'NEFL',
#    'ETV1',
#    'ASAP2',
#    'PSMC3',
#    'UGP2',
#    'SYN1',
#    'EFR3A',
#    'ARF3',
#    'PEX5L',
#    'ABR',
#    'HLA-B',
#    'GNPTAB',
#    'CACNG3',
#    'ITFG1',
#    'AP2S1',
#    'PCDH17',
#    'SLIT1',
#    'CDK5R2',
#    'SYNPR',
#    'MAP1A',
#    'CHMP4B',
#    'SLC25A22',
#    'PPP2CA',
#    'RBFOX3',
#    'CERS6',
#    'LY6E',
#    'STX1B',
#    'TMOD2',
#    'VAT1L',
#    'PTPRU',
#    'ATP6V1A',
#    'GUK1',
#    'MAPK8IP2',
#    'GALNT9',
#    'FGF13',
#    'TTC9B',
#    'MICAL2',
#    'CREG2',
#    'CDK5R1',
#    'RAB26',
#    'CADPS',
#    'GMFB',
#    'ARHGEF7',
#    'CTGF',
#    'GHITM',
#    'ATP6V0D1',
#    'PHF24',
#    'SCG3',
#    'HSPH1',
#    'FAM171B',
#    'PHYHIP',
#    'ID2',
#    'RNF11',
#    'PSD',
#    'ST8SIA3',
#    'RFPL1S',
#    'RAB3B',
#    'PEG3',
#    'FRRS1L',
#    'HCFC1R1',
#    'NRGN',
#    'TOLLIP',
#    'SH3GL2',
#    'CNIH2',
#    'HIVEP2',
#    'IDS',
#    'MTCH1',
#    'CELF2',
#    'MDH1',
#    'SNAP91',
#    'ARHGDIG',
#    'ATP6AP1',
#    'CALM2',
#    'IQSEC1',
#    'DYNC1I1',
#    'B4GAT1',
#    'ATP6AP2',
#    'PHACTR1',
#    'MAP2K4',
#    'HLF',
#    'NUAK1',
#    'RAB3A',
#    'HABP4',
#    'GNAO1',
#    'FAM131A',
#    'GFRA2',
#    'PDZD4',
#    'TMEM14A',
#    'PCSK1',
#    'FAM49B',
#    'ADGRB2',
#    'DMXL2',
#    'SSX2IP',
#    'GNG7',
#    'ATP5F1A',
#    'CCND2',
#    'STMN3',
#    'TOMM20',
#    'EXTL1',
#    'DMTN',
#    'CDK14',
#    'ATP6V0A1',
#    'ZYG11B',
#    'RTN4RL2',
#    'HINT1',
#    'CAB39L',
#    'ACTR3B',
#    'YWHAB',
#    'NAP1L2',
#    'ATCAY',
#    'CDIP1',
#    'IGSF21',
#    'CAMK2G',
#    'RAB3C',
#    'CCNI',
#    'SERINC3',
#    'YWHAH',
#    'LINGO1',
#    'BMPR2',
#    'EIF4A2',
#    'MPPED1',
#    'STUM',
#    'ABI2',
#    'NDFIP1',
#    'ATRNL1',
#    'PKM',
#    'AMPH',
#    'KCNMA1',
#    'NSMF',
#    'EPAS1',
#    'ATP6V1H',
#    'CAMKV',
#    'RHBDD2',
#    'ATL1',
#    'PGK1',
#    'PLEKHB2',
#    'PREPL',
#    'SCGB2A2',
#    'VGF',
#    'MEF2D',
#    'CALML5',
#    'SLC25A46',
#    'REEP2',
#    'MYO5A',
#    'BAMBI',
#    'GRIN2A',
#    'WDR47',
#    'DOCK3',
#    'OLFM1',
#    'RABGAP1L',
#    'NNAT',
#    'C9ORF16',
#    'RAB1A',
#    'OCIAD1',
#    'ENO2',
#    'MAPRE3',
#    'PNMA8B',
#    'CELF4',
#    'PDP1',
#    'NCAM2',
#    'KLHDC3',
#    'FAM49A',
#    'WSB2',
#    'GPI',
#    'DMD',
#    'CLIP3',
#    'FEM1B',
#    'STIM1',
#    'CDS2',
#    'ATP5F1B',
#    'TAGLN3',
#    'RTN4R',
#    'SCGB1D2',
#    'MEIS3',
#    'TUBB',
#    'BEX5',
#    'CRIM1',
#    'BEX1',
#    'GABBR2',
#    'ANK3',
#    'AKAP6',
#    'PSMB7',
#    'SAE1',
#    'SERPINI1',
#    'SPRN',
#    'MCTP1',
#    'ATP6V1C1',
#    'BEX4',
#    'CADPS2',
#    'FUT9',
#    'PGM2L1',
#    'TAF9',
#    'FAM155A',
#    'ATP2B2',
#    'KCNV1',
#    'PAK1',
#    'ARL6IP1',
#    'RPRML',
#    'ATP5MC3',
#    'ANK2',
#    'MTURN',
#    'NDUFA5',
#    'CHRM1',
#    'IFI27',
#    'PARP6',
#    'C1QTNF4',
#    'BNIP3',
#    'OXCT1',
#    'CHL1',
#    'GPR158',
#    'JAKMIP1',
#    'CAMK2B',
#    'COX7C',
#    'GSKIP',
#    'APBB1',
#    'UBXN6',
#    'KIF3C',
#    'SEZ6L2',
#    'PTPRN2',
#    'PNMA8A',
#    'CHD3',
#    'WLS',
#    'CACNB1',
#    'IFI6',
#    'PINK1',
#    'NDRG3',
#    'PNMA8C',
#    'SREBF2',
#    'EFNB2',
#    'NFIA',
#    'RGMA',
#    'PRKAR1B',
#    'SERINC1',
#    'SNRNP25',
#    'HSPA8',
#    'UBE2N',
#    'TMEM30A',
#    'TUSC2',
#    'GABRA1',
#    'SOHLH1',
#    'KIAA0513',
#    'UBE2V2',
#    'FAM3C',
#    'TIMM17A',
#    'DYNLL2',
#    'NEUROD2',
#    'CCDC3',
#    'NCOA7',
#    'NR3C1',
#    'GPR162',
#    'PRNP',
#    'NT5C3B',
#    'ATP9A',
#    'GABRG2',
#    'GPCPD1',
#    'SULT4A1',
#    'RNF157',
#    'PRR36',
#    'ACOT7',
#    'CPLX1',
#    'PPP2R2D',
#    'BRWD1',
#    'ERC2',
#    'LZTS3',
#    'NREP',
#    'NPRL3',
#    'SARAF',
#    'DOK6',
#    'HSPA12A',
#    'ITPK1',
#    'NAP1L3',
#    'CYB5R1',
#    'TAPBP',
#    'GOT1',
#    'EIF4E3',
#    'SERPINF1',
#    'DEAF1',
#    'FBXO41',
#    'RASA1',
#    'CPEB3',
#    'CX3CL1',
#    'CDKN2D',
#    'FXYD7',
#    'ARPC5L',
#    'GNB1',
#    'LRP3',
#    'TRIM37',
#    'SLC8A2',
#    'THRA',
#    'SYP',
#    'SCN2B',
#    'PFKP',
#    'CSGALNACT1',
#    'ARL4D',
#    'SHC3',
#    'GNB4',
#    'KIAA1549L',
#    'PTMS',
#    'ELAVL4',
#    'TESC',
#    'SLC39A10',
#    'EPN1',
#    'C3ORF80',
#    'HECTD4',
#    'PRPS1',
#    'PPFIA3',
#    'TSPAN13',
#    'SORBS2',
#    'MAPK11',
#    'PPL',
#    'CAMSAP2',
#    'PRSS3',
#    'FLOT2',
#    'PRICKLE2',
#    'MLF2',
#    'COX5A',
#    'SYT5',
#    'PAPSS1',
#    'AGAP2',
#    'KIF3B',
#    'STARD13',
#    'EVL',
#    'TOMM70',
#    'VPS13A',
#    'FSD1',
#    'STRAP',
#    'FAM217B',
#    'TEX2',
#    'TLE4',
#    'MAP4K3',
#    'GPD1L',
#    'SYNPO',
#    'DUSP3',
#    'GLS',
#    'SGSM2',
#    'CAPRIN1',
#    'RUNDC3A',
#    'AP3S1',
#    'HNRNPA0',
#    'CASKIN1',
#    'S100P',
#    'BAP1',
#    'GNG3',
#    'USP2',
#    'FKBP1A',
#    'PDE4A',
#    'KCNH3',
#    'PLD3',
#    'GABARAPL1',
#    'SLC25A23',
#    'ATP6V0B',
#    'ADGRB3',
#    'VPS13D',
#    'APBA2',
#    'BRINP1',
#    'APLP2',
#    'APP',
#    'AREL1',
#    'DDN',
#    'LRP11',
#    'PAFAH1B1',
#    'BSG',
#    'STXBP5',
#    'GAP43',
#    'CMAS',
#    'ENTPD6',
#    'ATE1',
#    'HMGCS1',
#    'ATP2A2']}}

# %%
from find_cluster_degs import *
adata = read('/home/zuolulu/spatialDEG/test/results.h5ad')
spa_degs = find_spatial_cluster_degs(test_group=5,adata=adata,x=None,y=None,group='group')
# Out:
# identifying top markers for each group: 19130it [04:18, 73.99it/s]

# %%
spa_degs
# Out:
#         gene  test_group control_group  ratio_expr  diff_ratio_expr    log2fc  \
# 0       PLP1           5           [4]    1.000000         0.024691  0.426622
# 1        MBP           5           [4]    1.000000         0.009877  0.314678
# 2      CRYAB           5           [4]    1.000000         0.130864  0.677633
# 3        CNP           5           [4]    0.997674         0.133477  0.646377
# 4      PTGDS           5           [4]    1.000000         0.054321  0.417861
# ...      ...         ...           ...         ...              ...       ...
# 1346   SURF4           5           [4]    0.276744         0.074275  0.385660
# 1347   ZCRB1           5           [4]    0.339535         0.085214  0.341619
# 1348  MRPL14           5           [4]    0.197674         0.061872  0.561522
# 1349   PSMA2           5           [4]    0.227907         0.072351  0.375229
# 1350  LUC7L2           5           [4]    0.195349         0.066954  0.351362
#
#               pval          qval
# 0     3.680169e-91  1.595363e-87
# 1     5.764634e-91  1.595363e-87
# 2     4.276899e-83  7.890879e-80
# 3     1.338631e-74  1.852331e-71
# 4     2.325580e-60  2.574418e-57
# ...            ...           ...
# 1346  1.717233e-02  4.912086e-02
# 1347  1.723613e-02  4.927788e-02
# 1348  1.731316e-02  4.947254e-02
# 1349  1.735003e-02  4.953033e-02
# 1350  1.743583e-02  4.974605e-02
#
# [1351 rows x 8 columns]

# %%
from find_cluster_degs import *
adata = read('/home/zuolulu/spatialDEG/test/results.h5ad')
find_cluster_degs(adata,group='group',test_group=5,control_groups=[1,2,3,4,5,6],genes=None,method=None)
# Out:
# identifying top markers for each group: 19130it [05:12, 61.31it/s]
#          gene  test_group  control_group  ratio_expr  diff_ratio_expr  \
# 0        MOBP           5              3    0.983721         0.666074
# 1        GFAP           5              3    1.000000         0.319328
# 2         MBP           5              3    1.000000         0.005042
# 3        PLP1           5              3    1.000000         0.070588
# 4       CRYAB           5              3    1.000000         0.230252
# ...       ...         ...            ...         ...              ...
# 7929     NGDN           5              6    0.120930         0.041220
# 7930  TBL1XR1           5              2    0.286047         0.098547
# 7931    SMC1A           5              3    0.109302         0.035353
# 7932  SELENOT           5              4    0.367442         0.090899
# 7933     TNKS           5              4    0.211628         0.065949
#
#         log2fc           pval           qval
# 0     3.211881  7.736265e-167  2.569214e-162
# 1     2.297066  1.881832e-165  3.124782e-161
# 2     1.247987  1.042128e-164  1.153636e-160
# 3     1.637184  1.603440e-164  1.331256e-160
# 4     1.910007  1.829638e-163  1.215246e-159
# ...        ...            ...            ...
# 7929  0.753768   2.376111e-02   4.961374e-02
# 7930  0.148647   2.384040e-02   4.976364e-02
# 7931  1.086484   2.385714e-02   4.979546e-02
# 7932  0.290969   2.391520e-02   4.991351e-02
# 7933  0.314948   2.395138e-02   4.998273e-02
#
# [7934 rows x 8 columns]

# %%
from find_cluster_degs import *
adata = read('/home/zuolulu/spatialDEG/test/results.h5ad')
find_cluster_degs(adata,group='group',test_group=5,control_groups=[1,2,3,4,5,6],genes=None)
# Out:
# identifying top markers for each group: 19130it [04:26, 71.79it/s]
#         gene  test_group       control_group  ratio_expr  diff_ratio_expr  \
# 0        MBP           5  [1, 2, 3, 4, 5, 6]    1.000000         0.016179
# 1       PLP1           5  [1, 2, 3, 4, 5, 6]    1.000000         0.081239
# 2      CRYAB           5  [1, 2, 3, 4, 5, 6]    1.000000         0.197246
# 3        CNP           5  [1, 2, 3, 4, 5, 6]    0.997674         0.232442
# 4       MOBP           5  [1, 2, 3, 4, 5, 6]    0.983721         0.485958
# ...      ...         ...                 ...         ...              ...
# 1443    TIA1           5  [1, 2, 3, 4, 5, 6]    0.160465         0.034820
# 1444    PHF3           5  [1, 2, 3, 4, 5, 6]    0.153488         0.032662
# 1445   STX16           5  [1, 2, 3, 4, 5, 6]    0.195349         0.034936
# 1446  IFNGR1           5  [1, 2, 3, 4, 5, 6]    0.172093         0.034055
# 1447  WASHC1           5  [1, 2, 3, 4, 5, 6]    0.225581         0.034531
#
#         log2fc           pval           qval
# 0     0.751090  2.111704e-168  1.168828e-164
# 1     0.989912  5.888916e-168  1.629758e-164
# 2     1.170201  1.091404e-163  2.013641e-160
# 3     1.219535  5.032653e-161  6.963933e-158
# 4     1.601416  1.317005e-160  1.457925e-157
# ...        ...            ...            ...
# 1443  0.449653   2.917311e-02   4.921934e-02
# 1444  0.508426   2.917591e-02   4.921934e-02
# 1445  0.442602   2.950237e-02   4.972461e-02
# 1446  0.466431   2.961952e-02   4.987650e-02
# 1447  0.372474   2.961724e-02   4.987650e-02
#
# [1448 rows x 8 columns]
