# %%
from find_cluster_degs import *
from find_cluster_degs import find_markers
adata = read('/home/zuolulu/spatialDEG/results.h5ad')
test_group = 0
control_groups =  list(range(1,6+1))
group = 'group'
genes = ['CAMK2N1','ENC1','HPCAL1','CCK','HOPX','MALAT1','SERPINE2','TESPA1','RASGRF2','FKBP1A']
find_markers(adata,group='group',test_group=0,control_groups=[1,2,3,4,5,6],genes=genes)
# Out:
# identifying top markers for each group: 10it [00:00, 45.85it/s]
#        gene  test_group  versus_group  ratio_expr  diff_ratio_expr    log2fc  \
# 0  SERPINE2           0             2    0.245455         0.158227  0.530406
# 1  SERPINE2           0             5    0.245455         0.136566  0.699518
# 2  SERPINE2           0             4    0.245455         0.103702  0.187296
#
#            pval      qval
# 0  1.770716e-07  0.000008
# 1  3.448821e-07  0.000008
# 2  1.537030e-03  0.024080

# %%
from find_cluster_degs import *
from find_cluster_degs import find_markers
adata = read('/home/zuolulu/spatialDEG/results.h5ad')
test_group = 0
control_groups =  list(range(1,6+1))
find_markers(adata,group='group',test_group=0,control_groups=[1,2,3,4,5,6])
# Out:
# identifying top markers for each group: 19130it [07:25, 42.92it/s]
#           gene  test_group  versus_group  ratio_expr  diff_ratio_expr  \
# 0         ENC1           0             5    0.998701         0.472035
# 1         NRGN           0             5    0.998701         0.094257
# 2        OLFM1           0             5    0.990909         0.215354
# 3          CCK           0             5    0.998701         0.258701
# 4        VSNL1           0             5    0.994805         0.214805
# ...        ...         ...           ...         ...              ...
# 21807     RAF1           0             6    0.198701         0.063516
# 21808    AP3B2           0             3    0.398701         0.076750
# 21809     CDO1           0             1    0.235065         0.060290
# 21810     SOX9           0             1    0.189610         0.052673
# 21811  DNTTIP1           0             6    0.142857         0.050265
#
#          log2fc           pval           qval
# ...

# %%
from find_cluster_degs import *
adata = read('/home/zuolulu/spatialDEG/results.h5ad')
genes = ['CAMK2N1','ENC1','HPCAL1','CCK','HOPX','MALAT1','SERPINE2','TESPA1','RASGRF2','FKBP1A']
adata = find_all_markers(adata,group='group',genes=genes)
print(adata)
print(adata.uns['cluster_markers'])
# Out:
# identifying top markers for each group: 10it [00:00, 44.44it/s]
# identifying top markers for each group: 10it [00:00, 45.43it/s]
# identifying top markers for each group: 10it [00:00, 44.86it/s]
# identifying top markers for each group: 10it [00:00, 44.57it/s]
# identifying top markers for each group: 10it [00:00, 45.40it/s]
# identifying top markers for each group: 10it [00:00, 45.19it/s]
# identifying top markers for each group: 10it [00:00, 43.12it/s]
# AnnData object with n_obs × n_vars = 3639 × 19130
#     obs: 'x1', 'x2', 'x3', 'x4', 'x5', 'n_counts', 'pred', 'group', 'x_array', 'y_array', 'x_pixel', 'y_pixel'
#     var: 'gene_ids', 'feature_types', 'genome', 'genename'
#     uns: 'pred_colors', 'refined_pred_colors', 'cluster_markers'
# {'deg_table':        gene test_group versus_group  ratio_expr  diff_ratio_expr    log2fc  \
# 0  SERPINE2          0            2    0.245455         0.158227  0.530406
# ...

# %%
from find_cluster_degs import *
adata = read('/home/zuolulu/spatialDEG/results.h5ad')
adata = find_all_markers(adata,group='group')
print(adata)
print(adata.uns['cluster_markers'])
# Out:
# identifying top markers for each group: 7738it [03:17, 37.82it/s]
